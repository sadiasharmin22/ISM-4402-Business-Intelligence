# %%
import pandas as pd
import numpy as np
Location = "C:/Users/sadia/OneDrive/Desktop/Business intelligence/datasets/gradedata.csv"
df = pd.read_csv(Location)
df.tail()
# Out:
#           fname     lname  gender  age  exercise  hours  grade  \
# 1995       Cody  Shepherd    male   19         1      8   80.1
# 1996  Geraldine  Peterson  female   16         4     18  100.0
# 1997   Mercedes      Leon  female   18         3     14   84.9
# 1998     Lucius   Rowland    male   16         1      7   69.1
# 1999      Linus    Morris    male   19         4     10   79.6
#
#                                           address
# 1995        982 West Street, Alexandria, VA 22304
# 1996   78 Morris Street, East Northport, NY 11731
# 1997        30 Glenridge Rd., Bountiful, UT 84010
# 1998  342 West Meadowbrook Lane, Helena, MT 59601
# 1999       81 Homestead Drive, Voorhees, NJ 08043

# %%
#create a random sample of 500 rows from that dataset
df.take(np.random.permutation(len(df))[:500])
# Out:
#           fname     lname  gender  age  exercise  hours  grade  \
# 1373     Amanda    Garner  female   14         2     11   75.7
# 1530     Roanna   Oconnor  female   19         3     15   81.6
# 1168      Karen     Mejia  female   17         4     17   88.7
# 1481  September    Norris  female   15         1     20  100.0
# 457        Myra   Parrish  female   19         5     15  100.0
# ...         ...       ...     ...  ...       ...    ...    ...
# 1117       Adam    Gordon    male   14         2      5   70.1
# 1830     Xander  Woodward    male   14         2      9   71.0
# 963      Hayley   Aguirre  female   19         4     14   85.8
# 1948    Ezekiel      Mays    male   19         2      7   74.5
# 1884     Angela     Watts  female   17         3      9   81.5
#
#                                           address
# 1373       7898 Country Dr., Stillwater, MN 55082
# 1530         400 Woodsman Street, Salem, MA 01970
# 1168         91 Bohemia Drive, Lakeland, FL 33801
# ...
