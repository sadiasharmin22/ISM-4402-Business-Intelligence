# %%
# Change the current directory to the one in which you have stored the datasets.
import os 
os.chdir ('C:/Users/..........')

# %%
# NOTE: The below Python code and text has been sourced from the 
# Book - A.J. Henley and D. Wolf, Learn Data Analysis with Python
# The Your Turn questions solutions have been created by Arjun Kadian

# %%
# CHAPTER 3

# %%
# Preparing Data Is Half the Battle

# %%
# The second step of data analysis is cleaning the data. Getting data ready for
# analytical tools can be a difficult task. Python and its libraries try to make it
# as easy as possible.
# With just a few lines of code, you will be able to get your data ready for
# analysis. You will be able to
# • clean the data;
# • create new variables; and
# • organize the data.

# %%
# Cleaning Data

# %%
# To be useful for most analytical tasks, data must be clean. This means it
# should be consistent, relevant, and standardized. In this chapter, you will
# learn how to
# • remove outliers;
# • remove inappropriate values;
# • remove duplicates;
# • remove punctuation;
# • remove whitespace;
# • standardize dates; and
# • standardize text.

# %%
# Calculating and Removing Outliers

# %%
# Assume you are collecting data on the people you went to high school
# with. What if you went to high school with Bill Gates? Now, even though
# the person with the second-highest net worth is only worth $1.5 million,
# the average of your entire class is pushed up by the billionaire at the top.
# Finding the outliers allows you to remove the values that are so high or so
# low that they skew the overall view of the data.

# %%
# We cover two main ways of detecting outliers:
# 1. Standard Deviations: If the data is normally
# distributed, then 95 percent of the data is within 1.96
# standard deviations of the mean. So we can drop the
# values either above or below that range.
# 2. Interquartile Range (IQR): The IQR is the
# difference between the 25 percent quantile and the
# 75 percent quantile. Any values that are either lower
# than Q1 - 1.5 x IQR or greater than Q3 + 1.5 x IQR are
# treated as outliers and removed.
# Let's see what these look like (Listings 3-1 and 3-2).

# %%
# Listing 3-1. Method 1: Standard Deviation 
import pandas as pd
Location = "datasets/gradedata.csv" 
df = pd.read_csv(Location) 
meangrade = df['grade'].mean()
stdgrade = df['grade'].std()
toprange = meangrade + stdgrade * 1.96 
botrange = meangrade - stdgrade * 1.96 
copydf = df
copydf = copydf.drop(copydf[copydf['grade'] > toprange].index)
copydf = copydf.drop(copydf[copydf['grade'] < botrange].index) 
copydf
# Out:
#           fname     lname  gender  age  exercise  hours  grade  \
# 0        Marcia      Pugh  female   17         3     10   82.4
# 1        Kadeem  Morrison    male   18         4      4   78.2
# 2          Nash    Powell    male   18         5      9   79.3
# 3       Noelani    Wagner  female   14         2      7   83.2
# 4       Noelani    Cherry  female   18         4     15   87.4
# ...         ...       ...     ...  ...       ...    ...    ...
# 1995       Cody  Shepherd    male   19         1      8   80.1
# 1996  Geraldine  Peterson  female   16         4     18  100.0
# 1997   Mercedes      Leon  female   18         3     14   84.9
# 1998     Lucius   Rowland    male   16         1      7   69.1
# 1999      Linus    Morris    male   19         4     10   79.6
#
#                                           address
# 0         9253 Richardson Road, Matawan, NJ 07747
# 1                33 Spring Dr., Taunton, MA 02780
# 2                41 Hill Avenue, Mentor, OH 44060
# ...

# %%
# Line 6: Here we calculate the upper range equal to 1.96
# times the standard deviation plus the mean.
# • Line 7: Here we calculate the lower range equal to
# 1.96 times the standard deviation subtracted from the
# mean.
# • Line 9: Here we drop the rows where the grade is higher
# than the toprange.
# • Line 11: Here we drop the rows where the grade is
# lower than the botrange.

# %%
# Listing 3-2. Method 2: Interquartile Range 
import pandas as pd
Location = "datasets/gradedata.csv" 
df = pd.read_csv(Location)
q1 = df['grade'].quantile(.25)
q3 = df['grade'].quantile(.75)
iqr = q3-q1
toprange = q3 + iqr * 1.5
botrange = q1 - iqr * 1.5
copydf = df
copydf = copydf.drop(copydf[copydf['grade'] > toprange].index)
copydf = copydf.drop(copydf[copydf['grade'] < botrange].index)
copydf
# Out:
#           fname     lname  gender  age  exercise  hours  grade  \
# 0        Marcia      Pugh  female   17         3     10   82.4
# 1        Kadeem  Morrison    male   18         4      4   78.2
# 2          Nash    Powell    male   18         5      9   79.3
# 3       Noelani    Wagner  female   14         2      7   83.2
# 4       Noelani    Cherry  female   18         4     15   87.4
# ...         ...       ...     ...  ...       ...    ...    ...
# 1995       Cody  Shepherd    male   19         1      8   80.1
# 1996  Geraldine  Peterson  female   16         4     18  100.0
# 1997   Mercedes      Leon  female   18         3     14   84.9
# 1998     Lucius   Rowland    male   16         1      7   69.1
# 1999      Linus    Morris    male   19         4     10   79.6
#
#                                           address
# 0         9253 Richardson Road, Matawan, NJ 07747
# 1                33 Spring Dr., Taunton, MA 02780
# 2                41 Hill Avenue, Mentor, OH 44060
# ...

# %%
# • Line 9: Here we calculate the upper boundary = the
# third quartile + 1.5 * the IQR.
# • Line 10: Here we calculate the lower boundary = the
# first quartile - 1.5 * the IQR.
# • Line 13: Here we drop the rows where the grade is
# higher than the toprange.
# • Line 14: Here we drop the rows where the grade is
# lower than the botrange.

# %%
# Your Turn!!!
# Load the dataset datasets/data1.xls. Can you remove the
# outliers? Try it with both methods.
# Solution!!!

# Method 1: Standard Deviation 
import pandas as pd
Location = "datasets/data1.xlsx" 
df = pd.read_excel(Location) 
meangrade = df['grade'].mean()
stdgrade = df['grade'].std()
toprange = meangrade + stdgrade * 1.96 
botrange = meangrade - stdgrade * 1.96 
copydf = df
copydf = copydf.drop(copydf[copydf['grade'] > toprange].index)
copydf = copydf.drop(copydf[copydf['grade'] < botrange].index) 
copydf
# Out:
#         fname  age  grade
# 0       Baker   14     90
# 1   Josephine   19    100
# 2      Calvin   15     66
# 3      Aretha   17     84
# 4   Britanney   19     66
# ..        ...  ...    ...
# 95  Shaeleigh   18     82
# 96     Vielka   14     80
# 97    Shelley   14     75
# 98    Merritt   15     73
# 99    Desirae   16     69
#
# [100 rows x 3 columns]

# %%
# Solution!!!

# Method 2: Interquartile Range 
import pandas as pd
Location = "datasets/data1.xlsx" 
df = pd.read_excel(Location)
q1 = df['grade'].quantile(.25)
q3 = df['grade'].quantile(.75)
iqr = q3-q1
toprange = q3 + iqr * 1.5
botrange = q1 - iqr * 1.5
copydf = df
copydf = copydf.drop(copydf[copydf['grade'] > toprange].index)
copydf = copydf.drop(copydf[copydf['grade'] < botrange].index)
copydf
# Out:
#         fname  age  grade
# 0       Baker   14     90
# 1   Josephine   19    100
# 2      Calvin   15     66
# 3      Aretha   17     84
# 4   Britanney   19     66
# ..        ...  ...    ...
# 95  Shaeleigh   18     82
# 96     Vielka   14     80
# 97    Shelley   14     75
# 98    Merritt   15     73
# 99    Desirae   16     69
#
# [100 rows x 3 columns]

# %%
# Missing Data in Pandas Dataframes

# %%
# One of the most annoying things about working with large datasets is
# finding the missing datum. It can make it impossible or unpredictable to
# compute most aggregate statistics or to generate pivot tables. If you look
# for missing data points in a 50-row dataset it is fairly easy. However, if you
# try to find a missing data point in a 500,000-row dataset it can be much
# tougher.
# Python's pandas library has functions to help you find, delete, or
# change missing data (Listing 3-3).

# %%
# Listing 3-3. Creating Dataframe with Missing Data
import pandas as pd
df = pd.read_csv("datasets/gradedata2.csv") 
df.head()
# Out:
#      fname     lname  gender  age  exercise  hours  grade  \
# 0   Marcia      Pugh  female   17         3     10   82.4
# 1   Kadeem  Morrison    male   18         4      4   78.2
# 2     Nash    Powell    male   18         5      9   79.3
# 3  Noelani    Wagner  female   14         2      7   83.2
# 4  Noelani    Cherry  female   18         4     15   87.4
#
#                                       address
# 0        7379 Highland Rd. , Dublin, GA 31021
# 1          8 Bayport St. , Honolulu, HI 96815
# 2           Encino, CA 91316, 3 Lilac Street
# 3  Riverview, FL 33569, 9998 North Smith Dr.
# 4   97 SE. Ocean Street , Bethlehem, PA 18015

# %%
# The preceding code loads a legitimate dataset that includes rows with
# missing data. We can use the resulting dataframe to practice dealing with
# missing data.
# To drop all the rows with missing (NaN) data, use the code shown in
# Listing 3-4.

# %%
# Listing 3-4. Drop Rows with Missing Data
df_no_missing = df.dropna()
df_no_missing
# Out:
#           fname     lname  gender  age  exercise  hours  grade  \
# 0        Marcia      Pugh  female   17         3     10   82.4
# 1        Kadeem  Morrison    male   18         4      4   78.2
# 2          Nash    Powell    male   18         5      9   79.3
# 3       Noelani    Wagner  female   14         2      7   83.2
# 4       Noelani    Cherry  female   18         4     15   87.4
# ...         ...       ...     ...  ...       ...    ...    ...
# 1995       Cody  Shepherd    male   19         1      8   80.1
# 1996  Geraldine  Peterson  female   16         4     18  100.0
# 1997   Mercedes      Leon  female   18         3     14   84.9
# 1998     Lucius   Rowland    male   16         1      7   69.1
# 1999      Linus    Morris    male   19         4     10   79.6
#
#                                                address
# 0                 7379 Highland Rd. , Dublin, GA 31021
# 1                   8 Bayport St. , Honolulu, HI 96815
# ...

# %%
# To add a column filled with empty values, use the code in Listing 3-5.

# %%
# Listing 3-5. Add a Column with Empty Values
import numpy as np 
df['newcol'] = np.nan 
df.head()
# Out:
#      fname     lname  gender  age  exercise  hours  grade  \
# 0   Marcia      Pugh  female   17         3     10   82.4
# 1   Kadeem  Morrison    male   18         4      4   78.2
# 2     Nash    Powell    male   18         5      9   79.3
# 3  Noelani    Wagner  female   14         2      7   83.2
# 4  Noelani    Cherry  female   18         4     15   87.4
#
#                                       address  newcol
# 0        7379 Highland Rd. , Dublin, GA 31021     NaN
# 1          8 Bayport St. , Honolulu, HI 96815     NaN
# 2           Encino, CA 91316, 3 Lilac Street      NaN
# 3  Riverview, FL 33569, 9998 North Smith Dr.      NaN
# 4   97 SE. Ocean Street , Bethlehem, PA 18015     NaN

# %%
# To drop any columns that contain nothing but empty values,
# see Listing 3-6.

# %%
# Listing 3-6. Drop Completely Empty Columns
df.dropna(axis=1,how='all')
# Out:
#           fname     lname  gender  age  exercise  hours  grade  \
# 0        Marcia      Pugh  female   17         3     10   82.4
# 1        Kadeem  Morrison    male   18         4      4   78.2
# 2          Nash    Powell    male   18         5      9   79.3
# 3       Noelani    Wagner  female   14         2      7   83.2
# 4       Noelani    Cherry  female   18         4     15   87.4
# ...         ...       ...     ...  ...       ...    ...    ...
# 1995       Cody  Shepherd    male   19         1      8   80.1
# 1996  Geraldine  Peterson  female   16         4     18  100.0
# 1997   Mercedes      Leon  female   18         3     14   84.9
# 1998     Lucius   Rowland    male   16         1      7   69.1
# 1999      Linus    Morris    male   19         4     10   79.6
#
#                                                address
# 0                 7379 Highland Rd. , Dublin, GA 31021
# 1                   8 Bayport St. , Honolulu, HI 96815
# ...

# %%
# To replace all empty values with zero, see Listing 3-7.

# %%
# Listing 3-7. Replace Empty Cells with 0
df.fillna(0)
# Out:
#           fname     lname  gender  age  exercise  hours  grade  \
# 0        Marcia      Pugh  female   17         3     10   82.4
# 1        Kadeem  Morrison    male   18         4      4   78.2
# 2          Nash    Powell    male   18         5      9   79.3
# 3       Noelani    Wagner  female   14         2      7   83.2
# 4       Noelani    Cherry  female   18         4     15   87.4
# ...         ...       ...     ...  ...       ...    ...    ...
# 1995       Cody  Shepherd    male   19         1      8   80.1
# 1996  Geraldine  Peterson  female   16         4     18  100.0
# 1997   Mercedes      Leon  female   18         3     14   84.9
# 1998     Lucius   Rowland    male   16         1      7   69.1
# 1999      Linus    Morris    male   19         4     10   79.6
#
#                                                address  newcol
# 0                 7379 Highland Rd. , Dublin, GA 31021     0.0
# 1                   8 Bayport St. , Honolulu, HI 96815     0.0
# ...

# %%
# To fill in missing grades with the mean value of grade, see Listing 3-8.

# %%
# Listing 3-8. Replace Empty Cells with Average of Column
df["grade"].fillna(df["grade"].mean(), inplace=True)
df.head()
# Out:
#      fname     lname  gender  age  exercise  hours  grade  \
# 0   Marcia      Pugh  female   17         3     10   82.4
# 1   Kadeem  Morrison    male   18         4      4   78.2
# 2     Nash    Powell    male   18         5      9   79.3
# 3  Noelani    Wagner  female   14         2      7   83.2
# 4  Noelani    Cherry  female   18         4     15   87.4
#
#                                       address  newcol
# 0        7379 Highland Rd. , Dublin, GA 31021     NaN
# 1          8 Bayport St. , Honolulu, HI 96815     NaN
# 2           Encino, CA 91316, 3 Lilac Street      NaN
# 3  Riverview, FL 33569, 9998 North Smith Dr.      NaN
# 4   97 SE. Ocean Street , Bethlehem, PA 18015     NaN

# %%
# Note, inplace=True means that the changes are saved to the dataframe
# right away.
# To fill in missing grades with each gender's mean value of grade, see
# Listing 3-9.

# %%
# Listing 3-9. 
df["grade"].fillna(df.groupby("gender")
    ["grade"].transform("mean"), inplace=True)
df.head()
# Out:
#      fname     lname  gender  age  exercise  hours  grade  \
# 0   Marcia      Pugh  female   17         3     10   82.4
# 1   Kadeem  Morrison    male   18         4      4   78.2
# 2     Nash    Powell    male   18         5      9   79.3
# 3  Noelani    Wagner  female   14         2      7   83.2
# 4  Noelani    Cherry  female   18         4     15   87.4
#
#                                       address  newcol
# 0        7379 Highland Rd. , Dublin, GA 31021     NaN
# 1          8 Bayport St. , Honolulu, HI 96815     NaN
# 2           Encino, CA 91316, 3 Lilac Street      NaN
# 3  Riverview, FL 33569, 9998 North Smith Dr.      NaN
# 4   97 SE. Ocean Street , Bethlehem, PA 18015     NaN

# %%
# We can also select some rows but ignore the ones with missing data
# points. To select the rows of df where age is not NaN and gender is not
# NaN, see Listing 3-10.

# %%
# Listing 3-10. Selecting Rows with No Missing Age or Gender
df[df['age'].notnull() & df['gender'].notnull()]
df.head()
# Out:
#      fname     lname  gender  age  exercise  hours  grade  \
# 0   Marcia      Pugh  female   17         3     10   82.4
# 1   Kadeem  Morrison    male   18         4      4   78.2
# 2     Nash    Powell    male   18         5      9   79.3
# 3  Noelani    Wagner  female   14         2      7   83.2
# 4  Noelani    Cherry  female   18         4     15   87.4
#
#                                       address  newcol
# 0        7379 Highland Rd. , Dublin, GA 31021     NaN
# 1          8 Bayport St. , Honolulu, HI 96815     NaN
# 2           Encino, CA 91316, 3 Lilac Street      NaN
# 3  Riverview, FL 33569, 9998 North Smith Dr.      NaN
# 4   97 SE. Ocean Street , Bethlehem, PA 18015     NaN

# %%
# Your Turn!!!
# Load the dataset datasets/missinggrade.csv. Your mission, if you
# choose to accept it, is to delete rows with missing grades and to replace the
# missing values in hours of exercise by the mean value for that gender.

# Solution!!! (part 1)
import pandas as pd
df = pd.read_csv("datasets/missinggrade.csv")
df
# Out:
#           fname     lname  gender  age  exercise hours grade  \
# 0        Marcia      Pugh  female   17         3    10
# 1        Kadeem  Morrison    male   18         4        78.2
# 2          Nash    Powell    male   18         5     9
# 3       Noelani    Wagner  female   14         2     7  83.2
# 4       Noelani    Cherry  female   18         4        87.4
# ...         ...       ...     ...  ...       ...   ...   ...
# 1995       Cody  Shepherd    male   19         1     8  80.1
# 1996  Geraldine  Peterson  female   16         4    18
# 1997   Mercedes      Leon  female   18         3    14  84.9
# 1998     Lucius   Rowland    male   16         1     7  69.1
# 1999      Linus    Morris    male   19         4    10  79.6
#
#                                           address
# 0         9253 Richardson Road, Matawan, NJ 07747
# 1                33 Spring Dr., Taunton, MA 02780
# 2                41 Hill Avenue, Mentor, OH 44060
# ...

# %%
# Solution!!! (part 2)
df['grade'] = pd.to_numeric(df['grade'], errors ='coerce')
df["grade"].fillna(df.groupby("gender") ["grade"].transform("mean"), inplace=True)
df.head()
# Out:
#      fname     lname  gender  age  exercise hours      grade  \
# 0   Marcia      Pugh  female   17         3    10  82.752642
# 1   Kadeem  Morrison    male   18         4        78.200000
# 2     Nash    Powell    male   18         5     9  82.356781
# 3  Noelani    Wagner  female   14         2     7  83.200000
# 4  Noelani    Cherry  female   18         4        87.400000
#
#                                     address
# 0   9253 Richardson Road, Matawan, NJ 07747
# 1          33 Spring Dr., Taunton, MA 02780
# 2          41 Hill Avenue, Mentor, OH 44060
# 3        8839 Marshall St., Miami, FL 33125
# 4  8304 Charles Rd., Lewis Center, OH 43035

# %%
# Filtering Inappropriate Values

# %%
# Sometimes, if you are working with data you didn't collect yourself, you
# need to worry about whether the data is accurate. Heck, sometimes
# you need to worry about that even if you did collect it yourself! It can be 
# difficult to check the veracity of each and every data point, but it is quite
# easy to check if the data is appropriate.
# Python's pandas library has the ability to filter out the bad values
# (see Listing 3-11)

# %%
# Listing 3-11. Creating Dataset
import pandas as pd
names = ['Bob','Jessica','Mary','John','Mel'] 
grades = [76,-2,77,78,101]
GradeList = zip(names,grades)
df = pd.DataFrame(data = GradeList,
columns=['Names', 'Grades']) 
df
# Out:
#      Names  Grades
# 0      Bob      76
# 1  Jessica      -2
# 2     Mary      77
# 3     John      78
# 4      Mel     101

# %%
# To eliminate all the rows where the grades are too high, see Listing 3-12.

# %%
# Listing 3-12. Filtering Out Impossible Grades
df.loc[df['Grades'] <= 100]
# Out:
#      Names  Grades
# 0      Bob      76
# 1  Jessica      -2
# 2     Mary      77
# 3     John      78

# %%
# To change the out-of-bound values to the maximum or minimum
# allowed value, we can use the code seen in Listing 3-13.

# %%
# Listing 3-13. Changing Impossible Grades
df.loc[(df['Grades'] >= 100), 'Grades'] = 100
df.head()
# Out:
#      Names  Grades
# 0      Bob      76
# 1  Jessica      -2
# 2     Mary      77
# 3     John      78
# 4      Mel     100

# %%
# Your Turn!!! (Workbook Assignment 3)
# Using the dataset from this section, can you replace all the subzero grades
# with a grade of zero?

# %%
# Finding Duplicate Rows

# %%
# Another thing you need to worry about if you are using someone else’s
# data is whether any data is duplicated. (Did the same data get reported
# twice, or recorded twice, or just copied and pasted?) Heck, sometimes
# you need to worry about that even if you did collect it yourself! It can be
# difficult to check the veracity of each and every data point, but it is quite
# easy to check if the data is duplicated.
# Python's pandas library has a function for finding not only duplicated
# rows, but also the unique rows (Listing 3-14).

# %%
# Listing 3-14. Creating Dataset with Duplicates
import pandas as pd
names = ['Jan','John','Bob','Jan','Mary','Jon','Mel','Mel'] 
grades = [95,78,76,95,77,78,99,100]
GradeList = zip(names,grades)
df = pd.DataFrame(data = GradeList,
    columns=['Names', 'Grades'])
df
# Out:
#   Names  Grades
# 0   Jan      95
# 1  John      78
# 2   Bob      76
# 3   Jan      95
# 4  Mary      77
# 5   Jon      78
# 6   Mel      99
# 7   Mel     100

# %%
# To indicate the duplicate rows, we can simply run the code seen in
# Listing 3-15.

# %%
# Listing 3-15. Displaying Only Duplicates in the Dataframe
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5    False
# 6    False
# 7    False
# dtype: bool

# %%
# To show the dataset without duplicates, we can run the code seen in
# Listing 3-16.

# %%
# Listing 3-16. Displaying Dataset without Duplicates
df.drop_duplicates()
# Out:
#   Names  Grades
# 0   Jan      95
# 1  John      78
# 2   Bob      76
# 4  Mary      77
# 5   Jon      78
# 6   Mel      99
# 7   Mel     100

# %%
# You might be asking, “What if the entire row isn't duplicated, but I
# still know it's a duplicate?" This can happen if someone does your survey
# or retakes an exam again, so the name is the same, but the observation
# is different. In this case, where we know that a duplicate name means a
# duplicate entry, we can use the code seen in Listing 3-17.

# %%
# Listing 3-17. Drop Rows with Duplicate Names, Keeping the Last
# Observation
df.drop_duplicates(['Names'], keep='last')
# Out:
#   Names  Grades
# 1  John      78
# 2   Bob      76
# 3   Jan      95
# 4  Mary      77
# 5   Jon      78
# 7   Mel     100

# %%
# Your Turn!!!
# Load the dataset datasets/dupedata.csv. We figure people with the same
# address are duplicates. Can you drop the duplicated rows while keeping
# the first?

# Solution!!!(part 1)

# Note that the address for Marcia and Neil is same. As per the question 
# we need to keep the row for Marica and remove the data for Neil
import pandas as pd
df = pd.read_csv("datasets/dupedata.csv")
df
# Out:
#      fname     lname  gender  age  exercise  hours  grade  \
# 0   Marcia      Pugh  female   17         3     10   82.4
# 1   Kadeem  Morrison    male   18         4      4   78.2
# 2     Nash    Powell    male   18         5      9   79.3
# 3  Noelani    Wagner  female   14         2      7   83.2
# 4  Noelani    Cherry  female   18         4     15   87.4
# 5     Neil   Whitley    male   16         5     16   88.7
#
#                                     address
# 0   9253 Richardson Road, Matawan, NJ 07747
# 1          33 Spring Dr., Taunton, MA 02780
# 2          41 Hill Avenue, Mentor, OH 44060
# 3        8839 Marshall St., Miami, FL 33125
# 4  8304 Charles Rd., Lewis Center, OH 43035
# 5   9253 Richardson Road, Matawan, NJ 07747

# %%
# Solution!!!(part 2)
# The below code will check for duplicate addresses and will retain the data for 
# the first entry in the duplicate set
df.drop_duplicates(['address'],keep='first')
# Out:
#      fname     lname  gender  age  exercise  hours  grade  \
# 0   Marcia      Pugh  female   17         3     10   82.4
# 1   Kadeem  Morrison    male   18         4      4   78.2
# 2     Nash    Powell    male   18         5      9   79.3
# 3  Noelani    Wagner  female   14         2      7   83.2
# 4  Noelani    Cherry  female   18         4     15   87.4
#
#                                     address
# 0   9253 Richardson Road, Matawan, NJ 07747
# 1          33 Spring Dr., Taunton, MA 02780
# 2          41 Hill Avenue, Mentor, OH 44060
# 3        8839 Marshall St., Miami, FL 33125
# 4  8304 Charles Rd., Lewis Center, OH 43035

# %%
# Removing Punctuation from Column Contents

# %%
# Whether in a phone number or an address, you will often find unwanted
# punctuation in your data. Let's load some data to see how to address that
# (Listing 3-18).

# %%
# Listing 3-18. Loading Dataframe with Data from CSV File
import pandas as pd
Location = "datasets/gradedata.csv"
## To add headers as we load the data... 
df = pd.read_csv(Location)
df.head()
# Out:
#      fname     lname  gender  age  exercise  hours  grade  \
# 0   Marcia      Pugh  female   17         3     10   82.4
# 1   Kadeem  Morrison    male   18         4      4   78.2
# 2     Nash    Powell    male   18         5      9   79.3
# 3  Noelani    Wagner  female   14         2      7   83.2
# 4  Noelani    Cherry  female   18         4     15   87.4
#
#                                     address
# 0   9253 Richardson Road, Matawan, NJ 07747
# 1          33 Spring Dr., Taunton, MA 02780
# 2          41 Hill Avenue, Mentor, OH 44060
# 3        8839 Marshall St., Miami, FL 33125
# 4  8304 Charles Rd., Lewis Center, OH 43035

# %%
# To remove the unwanted punctuation, we create a function that
# returns all characters that aren't punctuation, and them we apply that
# function to our dataframe (Listing 3-19).

# %%
# Listing 3-19. Stripping Punctuation from the Address Column
import string
exclude = set(string.punctuation) 
print(exclude)
def remove_punctuation(x):
    try:
        x = ''.join(ch for ch in x if ch not in exclude)
    except: 
        pass
    return x
df.address = df.address.apply(remove_punctuation) 
df
# Out:
# {'\\', '!', '/', '`', ']', '{', '(', '+', '@', '~', '.', '#', '?', '<', "'", '[', '=', ';', '*', '>', '}', '&', ')', '_', '-', '|', ',', '%', '^', ':', '$', '"'}
#           fname     lname  gender  age  exercise  hours  grade  \
# 0        Marcia      Pugh  female   17         3     10   82.4
# 1        Kadeem  Morrison    male   18         4      4   78.2
# 2          Nash    Powell    male   18         5      9   79.3
# 3       Noelani    Wagner  female   14         2      7   83.2
# 4       Noelani    Cherry  female   18         4     15   87.4
# ...         ...       ...     ...  ...       ...    ...    ...
# 1995       Cody  Shepherd    male   19         1      8   80.1
# 1996  Geraldine  Peterson  female   16         4     18  100.0
# 1997   Mercedes      Leon  female   18         3     14   84.9
# 1998     Lucius   Rowland    male   16         1      7   69.1
# 1999      Linus    Morris    male   19         4     10   79.6
#
#                                         address
# ...

# %%
# Removing Whitespace from Column Contents

# %%
# Listing 3-20. Loading Dataframe with Data from CSV File
import pandas as pd
Location = "datasets/gradedata.csv"
## To add headers as we load the data... 
df = pd.read_csv(Location)
df.head()
# Out:
#      fname     lname  gender  age  exercise  hours  grade  \
# 0   Marcia      Pugh  female   17         3     10   82.4
# 1   Kadeem  Morrison    male   18         4      4   78.2
# 2     Nash    Powell    male   18         5      9   79.3
# 3  Noelani    Wagner  female   14         2      7   83.2
# 4  Noelani    Cherry  female   18         4     15   87.4
#
#                                     address
# 0   9253 Richardson Road, Matawan, NJ 07747
# 1          33 Spring Dr., Taunton, MA 02780
# 2          41 Hill Avenue, Mentor, OH 44060
# 3        8839 Marshall St., Miami, FL 33125
# 4  8304 Charles Rd., Lewis Center, OH 43035

# %%
# To remove the whitespace, we create a function that returns all
# characters that aren't punctuation, and them we apply that function to our
# dataframe (Listing 3-21).

# %%
# Listing 3-21. Stripping Whitespace from the Address Column
def remove_whitespace(x):
    try:
        x = ''.join(x.split()) 
    except:
        pass 
    return x
df.address = df.address.apply(remove_whitespace) 
df
# Out:
#           fname     lname  gender  age  exercise  hours  grade  \
# 0        Marcia      Pugh  female   17         3     10   82.4
# 1        Kadeem  Morrison    male   18         4      4   78.2
# 2          Nash    Powell    male   18         5      9   79.3
# 3       Noelani    Wagner  female   14         2      7   83.2
# 4       Noelani    Cherry  female   18         4     15   87.4
# ...         ...       ...     ...  ...       ...    ...    ...
# 1995       Cody  Shepherd    male   19         1      8   80.1
# 1996  Geraldine  Peterson  female   16         4     18  100.0
# 1997   Mercedes      Leon  female   18         3     14   84.9
# 1998     Lucius   Rowland    male   16         1      7   69.1
# 1999      Linus    Morris    male   19         4     10   79.6
#
#                                     address
# 0        9253RichardsonRoad,Matawan,NJ07747
# 1               33SpringDr.,Taunton,MA02780
# 2               41HillAvenue,Mentor,OH44060
# ...

# %%
# Standardizing Dates

# %%
# One of the problems with consolidating data from different sources is that
# different people and different systems can record dates differently. Maybe
# they use 01/03/1980 or they use 01/03/80 or even they use 1980/01/03.
# Even though they all refer to January 3, 1980, analysis tools may not
# recognize them all as dates if you are switching back and forth between the
# different formats in the same column (Listing 3-22)

# %%
# Listing 3-22. Creating Dataframe with Different Date Formats
import pandas as pd
names = ['Bob','Jessica','Mary','John','Mel'] 
grades = [76,95,77,78,99]
bsdegrees = [1,1,0,0,1]
msdegrees = [2,1,0,0,0]
phddegrees = [0,1,0,0,0]
bdates = ['1/1/1945','10/21/76','3/3/90',
          '04/30/1901','1963-09-01']
GradeList = zip(names,grades,bsdegrees,msdegrees,
                phddegrees,bdates) 
columns=['Names','Grades','BS','MS','PhD',"bdates"] 
df = pd.DataFrame(data = GradeList, columns=columns) 
df
# Out:
#      Names  Grades  BS  MS  PhD      bdates
# 0      Bob      76   1   2    0    1/1/1945
# 1  Jessica      95   1   1    1    10/21/76
# 2     Mary      77   0   0    0      3/3/90
# 3     John      78   0   0    0  04/30/1901
# 4      Mel      99   1   0    0  1963-09-01

# %%
# Listing 3-23 shows a function that standardizes dates to single format

# %%
# Listing 3-23. Function to Standardize Dates
from time import strftime
from datetime import datetime

def standardize_date(thedate):
    formatted_date = ""
    thedate = str(thedate)
    if not thedate or thedate.lower() == "missing" or thedate == "nan":
        formatted_date = "MISSING"
    if thedate.lower().find('x') != -1:
        formatted_date = "Incomplete"
    if thedate[0:2] == "00":
        formatted_date = thedate.replace("00", "19")
    try:
        formatted_date = str(datetime.strptime(thedate,'%m/%d/%y').strftime('%m/%d/%y')) 
    except:
        pass 
    try:
        formatted_date = str(datetime.strptime(thedate, '%m/%d/%Y').strftime('%m/%d/%y'))
    except:
        pass 
    try:
        if int(thedate[0:4]) < 1900:
            formatted_date = "Incomplete"
        else:
            formatted_date = str(datetime.strptime( thedate, '%Y-%m-%d').strftime('%m/%d/%y'))
    except:
        pass
    return formatted_date

# %%
# Now that we have this function, we can apply it to the birthdates
# column on our dataframe (Listing 3-24).

# %%
# Listing 3-24. Applying Date Standardization to Birthdate Column
df.bdates = df.bdates.apply(standardize_date)
df
# Out:
#      Names  Grades  BS  MS  PhD    bdates
# 0      Bob      76   1   2    0  01/01/45
# 1  Jessica      95   1   1    1  10/21/76
# 2     Mary      77   0   0    0  03/03/90
# 3     John      78   0   0    0  04/30/01
# 4      Mel      99   1   0    0  09/01/63

# %%
# Standardizing Text like SSNs, Phone Numbers,
# and Zip Codes

# %%
# One of the problems with consolidating data from different sources is that
# different people and different systems can record certain data like Social
# Security numbers, phone numbers, and zip codes differently. Maybe they use
# hyphens in those numbers, and maybe they don't. This section quickly covers
# how to standardize how these types of data are stored (see Listing 3-25).

# %%
# Listing 3-25. Creating Dataframe with SSNs
import pandas as pd
names = ['Bob','Jessica','Mary','John','Mel'] 
grades = [76,95,77,78,99]
bsdegrees = [1,1,0,0,1]
msdegrees = [2,1,0,0,0]
phddegrees = [0,1,0,0,0]
ssns = ['867-53-0909','333-22-4444','123-12-1234','777-93-9311','123-12-1423']
GradeList = zip(names,grades,bsdegrees,msdegrees, phddegrees,ssns)
columns=['Names','Grades','BS','MS','PhD',"ssn"]
df = pd.DataFrame(data = GradeList, columns=columns) 
df
# Out:
#      Names  Grades  BS  MS  PhD          ssn
# 0      Bob      76   1   2    0  867-53-0909
# 1  Jessica      95   1   1    1  333-22-4444
# 2     Mary      77   0   0    0  123-12-1234
# 3     John      78   0   0    0  777-93-9311
# 4      Mel      99   1   0    0  123-12-1423

# %%
# The code in Listing 3-26 creates a function that standardizes the SSNs
# and applies it to our ssn column.

# %%
# Listing 3-26. Remove Hyphens from SSNs and Add Leading Zeros if
# Necessary
def right(s, amount):
    return s[-amount]
def standardize_ssn(ssn):
    try:
        ssn = ssn.replace("-","")
        ssn = "".join(ssn.split())
        if len(ssn)<9 and ssn != 'Missing':
            ssn="000000000" + ssn
            ssn=right(ssn,9) 
    except:
        pass
    return ssn
df.ssn = df.ssn.apply(standardize_ssn) 
df
# Out:
#      Names  Grades  BS  MS  PhD        ssn
# 0      Bob      76   1   2    0  867530909
# 1  Jessica      95   1   1    1  333224444
# 2     Mary      77   0   0    0  123121234
# 3     John      78   0   0    0  777939311
# 4      Mel      99   1   0    0  123121423

# %%
# Creating New Variables

# %%
# Once the data is free of errors, you need to set up the variables that will
# directly answer your questions. It's a rare dataset in which every question
# you need answered is directly addressed by a variable. So, you may need to 
# do a lot of recoding and computing of variables to get exactly the dataset
# that you need.
# Examples include the following:
#  • Creating bins (like converting numeric grades to letter
#    grades or ranges of dates into Q1, Q2, etc.)
#  • Creating a column that ranks the values in another
#    column
#  • Creating a column to indicate that another value has
#    reached a threshold (passing or failing, Dean's list, etc.)
#  • Converting string categories to numbers (for regression
#    or correlation)

# %%
# Binning Data

# %%
# Sometimes, you will have discrete data that you need to group into bins.
# (Think: converting numeric grades to letter grades.) In this lesson, we will
# learn about binning (Listing 3-27).

# %%
# Listing 3-27. Loading the Dataset from CSV
import pandas as pd
Location = "datasets/gradedata.csv" 
df = pd.read_csv(Location) 
df.head()
# Out:
#      fname     lname  gender  age  exercise  hours  grade  \
# 0   Marcia      Pugh  female   17         3     10   82.4
# 1   Kadeem  Morrison    male   18         4      4   78.2
# 2     Nash    Powell    male   18         5      9   79.3
# 3  Noelani    Wagner  female   14         2      7   83.2
# 4  Noelani    Cherry  female   18         4     15   87.4
#
#                                     address
# 0   9253 Richardson Road, Matawan, NJ 07747
# 1          33 Spring Dr., Taunton, MA 02780
# 2          41 Hill Avenue, Mentor, OH 44060
# 3        8839 Marshall St., Miami, FL 33125
# 4  8304 Charles Rd., Lewis Center, OH 43035

# %%
# Now that the data is loaded, we need to define the bins and group
# names (Listing 3-28).

# %%
# Listing 3-28. Define Bins as 0 to 60, 60 to 70, 70 to 80, 80 to 90,
# 90 to 100
# Create the bin dividers
bins = [0, 60, 70, 80, 90, 100]
# Create names for the four groups 
group_names = ['F', 'D', 'C', 'B', 'A']

# %%
# Notice that there is one more bin value than there are group_names.
# This is because there needs to be a top and bottom limit for each bin.

# %%
# Listing 3-29. Cut Grades
df['lettergrade'] = pd.cut(df['grade'], bins, labels=group_names)
df
# Out:
#           fname     lname  gender  age  exercise  hours  grade  \
# 0        Marcia      Pugh  female   17         3     10   82.4
# 1        Kadeem  Morrison    male   18         4      4   78.2
# 2          Nash    Powell    male   18         5      9   79.3
# 3       Noelani    Wagner  female   14         2      7   83.2
# 4       Noelani    Cherry  female   18         4     15   87.4
# ...         ...       ...     ...  ...       ...    ...    ...
# 1995       Cody  Shepherd    male   19         1      8   80.1
# 1996  Geraldine  Peterson  female   16         4     18  100.0
# 1997   Mercedes      Leon  female   18         3     14   84.9
# 1998     Lucius   Rowland    male   16         1      7   69.1
# 1999      Linus    Morris    male   19         4     10   79.6
#
#                                           address lettergrade
# 0         9253 Richardson Road, Matawan, NJ 07747           B
# 1                33 Spring Dr., Taunton, MA 02780           C
# ...

# %%
# Listing 3-29 categorizes the column grade based on the bins list and
# labels the values using the group_names list.
# And if we want to count the number of observations for each category,
# we can do that too (Listing 3-30).

# %%
# Listing 3-30. Count Number of Observations
pd.value_counts(df['lettergrade'])
# Out:
# B    737
# C    580
# A    475
# D    193
# F     15
# Name: lettergrade, dtype: int64

# %%
# Your Turn!!!(Workbook Assignment 4)
# Recreate the dataframe from this section and create a column classifying
# the row as pass or fail. This is for a master's program that requires a grade
# of 80 or above for a student to pass.

# %%
# Applying Functions to Groups, Bins,
# and Columns

# %%
# The number one reason I use Python to analyze data is to handle datasets
# larger than a million rows. The number two reason is the ease of applying
# functions to my data.
# To see this, first we need to load up some data (Listing 3-31).

# %%
# Listing 3-31. Loading a Dataframe from a CSV File
import pandas as pd
Location = "datasets/gradedata.csv" 
df = pd.read_csv(Location) 
df.head()
# Out:
#      fname     lname  gender  age  exercise  hours  grade  \
# 0   Marcia      Pugh  female   17         3     10   82.4
# 1   Kadeem  Morrison    male   18         4      4   78.2
# 2     Nash    Powell    male   18         5      9   79.3
# 3  Noelani    Wagner  female   14         2      7   83.2
# 4  Noelani    Cherry  female   18         4     15   87.4
#
#                                     address
# 0   9253 Richardson Road, Matawan, NJ 07747
# 1          33 Spring Dr., Taunton, MA 02780
# 2          41 Hill Avenue, Mentor, OH 44060
# 3        8839 Marshall St., Miami, FL 33125
# 4  8304 Charles Rd., Lewis Center, OH 43035

# %%
# Listing 3-32. Using Bins
# Create the bin dividers
bins = [0, 60, 70, 80, 90, 100]
# Create names for the four groups 
group_names = ['F', 'D', 'C', 'B', 'A'] 
df['letterGrades'] = pd.cut(df['grade'],bins, labels=group_names) 
df.head()
# Out:
#      fname     lname  gender  age  exercise  hours  grade  \
# 0   Marcia      Pugh  female   17         3     10   82.4
# 1   Kadeem  Morrison    male   18         4      4   78.2
# 2     Nash    Powell    male   18         5      9   79.3
# 3  Noelani    Wagner  female   14         2      7   83.2
# 4  Noelani    Cherry  female   18         4     15   87.4
#
#                                     address letterGrades
# 0   9253 Richardson Road, Matawan, NJ 07747            B
# 1          33 Spring Dr., Taunton, MA 02780            C
# 2          41 Hill Avenue, Mentor, OH 44060            C
# 3        8839 Marshall St., Miami, FL 33125            B
# 4  8304 Charles Rd., Lewis Center, OH 43035            B

# %%
# To find the average hours of study by letter grade, we apply our
# functions to the binned column (Listing 3-33)

# %%
# Listing 3-33. Applying Function to Newly Created Bin
df.groupby('letterGrades')['hours'].mean()
# Out:
# letterGrades
# F     3.933333
# D     5.544041
# C     8.381034
# B    11.827680
# A    15.305263
# Name: hours, dtype: float64

# %%
# Applying a function to a column looks like Listing 3-34

# %%
# Listing 3-34. Applying a Function to a Column
# Applying the integer function to the grade column 
df['grade'] = df['grade'].apply(lambda x: int(x))
df.head()
# Out:
#      fname     lname  gender  age  exercise  hours  grade  \
# 0   Marcia      Pugh  female   17         3     10     82
# 1   Kadeem  Morrison    male   18         4      4     78
# 2     Nash    Powell    male   18         5      9     79
# 3  Noelani    Wagner  female   14         2      7     83
# 4  Noelani    Cherry  female   18         4     15     87
#
#                                     address letterGrades
# 0   9253 Richardson Road, Matawan, NJ 07747            B
# 1          33 Spring Dr., Taunton, MA 02780            C
# 2          41 Hill Avenue, Mentor, OH 44060            C
# 3        8839 Marshall St., Miami, FL 33125            B
# 4  8304 Charles Rd., Lewis Center, OH 43035            B

# %%
# Line 1: Let's get an integer value for each grade in the
# dataframe.
# Applying a function to a group can be seen in Listing 3-35.

# %%
# Listing 3-35. Applying a Function to a Group
gender_preScore = df['grade'].groupby(df['gender']) 
gender_preScore.mean()
# Out:
# gender
# female    82.341
# male      81.981
# Name: grade, dtype: float64

# %%
# • Line 1: Create a grouping object. In other words, create
#   an object that represents that particular grouping. In
#   this case, we group grades by the gender.
# • Line 2: Display the mean value of each regiment's
#   pre-test score.

# %%
# Your Turn!!!
# Import the datasets/gradedata.csv file and create a new binned column of the 'status' as either 
# passing (> 70) or failing (<=70). Then, compute the mean hours of exercise of the female students 
# with a 'status' of passing.

# Solution!!!(part 1)
import pandas as pd
Location = "datasets/gradedata.csv" 
df = pd.read_csv(Location) 
df.head()
# Out:
#      fname     lname  gender  age  exercise  hours  grade  \
# 0   Marcia      Pugh  female   17         3     10   82.4
# 1   Kadeem  Morrison    male   18         4      4   78.2
# 2     Nash    Powell    male   18         5      9   79.3
# 3  Noelani    Wagner  female   14         2      7   83.2
# 4  Noelani    Cherry  female   18         4     15   87.4
#
#                                     address
# 0   9253 Richardson Road, Matawan, NJ 07747
# 1          33 Spring Dr., Taunton, MA 02780
# 2          41 Hill Avenue, Mentor, OH 44060
# 3        8839 Marshall St., Miami, FL 33125
# 4  8304 Charles Rd., Lewis Center, OH 43035

# %%
# Solution!!!(part 2)
# Create the bin dividers
bins = [0, 70, 100]
# Create names for the four groups 
group_names = ['Failing', 'Passing'] 
df['FinalletterGrades'] = pd.cut(df['grade'],bins, labels=group_names) 
df.head()
# Out:
#      fname     lname  gender  age  exercise  hours  grade  \
# 0   Marcia      Pugh  female   17         3     10   82.4
# 1   Kadeem  Morrison    male   18         4      4   78.2
# 2     Nash    Powell    male   18         5      9   79.3
# 3  Noelani    Wagner  female   14         2      7   83.2
# 4  Noelani    Cherry  female   18         4     15   87.4
#
#                                     address FinalletterGrades
# 0   9253 Richardson Road, Matawan, NJ 07747           Passing
# 1          33 Spring Dr., Taunton, MA 02780           Passing
# 2          41 Hill Avenue, Mentor, OH 44060           Passing
# 3        8839 Marshall St., Miami, FL 33125           Passing
# 4  8304 Charles Rd., Lewis Center, OH 43035           Passing

# %%
# Solution!!!(part 3)
gender_preScore = df['exercise'].groupby(df['gender']) 
gender_preScore.mean()
# Out:
# gender
# female    3.047
# male      2.954
# Name: exercise, dtype: float64

# %%
# Ranking Rows of Data

# %%
# It is relatively easy to find the row with the maximum value or the
# minimum value, but sometimes you want to find the rows with the 50
# highest or the 100 lowest values for a particular column. This is when you
# need ranking (Listing 3-36).

# %%
# Listing 3-36. Load Data from CSV
import pandas as pd
Location = "datasets/gradedata.csv" 
df = pd.read_csv(Location) 
df.head()
# Out:
#      fname     lname  gender  age  exercise  hours  grade  \
# 0   Marcia      Pugh  female   17         3     10   82.4
# 1   Kadeem  Morrison    male   18         4      4   78.2
# 2     Nash    Powell    male   18         5      9   79.3
# 3  Noelani    Wagner  female   14         2      7   83.2
# 4  Noelani    Cherry  female   18         4     15   87.4
#
#                                     address
# 0   9253 Richardson Road, Matawan, NJ 07747
# 1          33 Spring Dr., Taunton, MA 02780
# 2          41 Hill Avenue, Mentor, OH 44060
# 3        8839 Marshall St., Miami, FL 33125
# 4  8304 Charles Rd., Lewis Center, OH 43035

# %%
# If we want to find the rows with the lowest grades, we will need to rank
# all rows in ascending order by grade. Listing 3-37 shows the code to create
# a new column that is the rank of the value of grade in ascending order.

# %%
# Listing 3-37. Create Column with Ranking by Grade
df['graderanked'] = df['grade'].rank(ascending=1)
df.tail()
# Out:
#           fname     lname  gender  age  exercise  hours  grade  \
# 1995       Cody  Shepherd    male   19         1      8   80.1
# 1996  Geraldine  Peterson  female   16         4     18  100.0
# 1997   Mercedes      Leon  female   18         3     14   84.9
# 1998     Lucius   Rowland    male   16         1      7   69.1
# 1999      Linus    Morris    male   19         4     10   79.6
#
#                                           address  graderanked
# 1995        982 West Street, Alexandria, VA 22304        794.0
# 1996   78 Morris Street, East Northport, NY 11731       1957.0
# 1997        30 Glenridge Rd., Bountiful, UT 84010       1158.5
# 1998  342 West Meadowbrook Lane, Helena, MT 59601        180.0
# 1999       81 Homestead Drive, Voorhees, NJ 08043        770.0

# %%
# So, if we just wanted to see the students with the 20 lowest grades, we
# would use the code in Listing 3-38.

# %%
# Listing 3-38. Bottom 20 Students
df[df['graderanked'] < 21]
# Out:
#            fname       lname  gender  age  exercise  hours  grade  \
# 340        Abbot        Hall    male   16         4      3   58.9
# 388       Colton       Ochoa    male   17         1      4   60.3
# 410        Linda     Baldwin  female   16         5      2   59.0
# 528      Chester       Vance    male   17         1      5   60.1
# 556        Lacey      Nieves  female   18         1      2   57.9
# 664        Alika       Poole  female   19         2     16   32.0
# 672       Ciaran         Gay    male   19         4      3   59.3
# 700       Steven     Sherman    male   18         1      2   60.0
# 869        Tanek    Stephens    male   15         1      4   60.5
# 972       Keegan   Rasmussen    male   19         4      3   43.0
# 1068      Isaiah  Harrington    male   17         1      4   58.9
# 1207       Selma       Stout  female   19         2      3   59.4
# 1237       Willa       Byers  female   14         2      4   59.2
# ...

# %%
# And, to see them in order, we need to use the code in Listing 3-39.

# %%
# Listing 3-39. Bottom 6 Students in Order
df[df['graderanked'] < 6].sort_values('graderanked')
# Out:
#        fname      lname  gender  age  exercise  hours  grade  \
# 664    Alika      Poole  female   19         2     16   32.0
# 972   Keegan  Rasmussen    male   19         4      3   43.0
# 1870    Levi    Coleman    male   19         3      3   55.9
# 1910    Gail     Mcneil  female   17         2      3   56.1
# 1494   Jenna     Wagner  female   16         1      3   56.3
#
#                                             address  graderanked
# 664     9282 Purple Finch Lane, Lexington, NC 27292          1.0
# 972   876 East Pilgrim Street, Chelmsford, MA 01824          2.0
# 1870      9453 Laurel Street, Jersey City, NJ 07302          3.0
# 1910            8409A Spruce St., Fishers, IN 46037          4.0
# 1494    8829 Shore Dr., Hopewell Junction, NY 12533          5.0

# %%
# Your Turn!!!
# Can you find the 50 students with the most hours of study per week?

# Solution!!!(part 1)

import pandas as pd
Location = "datasets/gradedata.csv" 
df = pd.read_csv(Location) 
df.head()
# Out:
#      fname     lname  gender  age  exercise  hours  grade  \
# 0   Marcia      Pugh  female   17         3     10   82.4
# 1   Kadeem  Morrison    male   18         4      4   78.2
# 2     Nash    Powell    male   18         5      9   79.3
# 3  Noelani    Wagner  female   14         2      7   83.2
# 4  Noelani    Cherry  female   18         4     15   87.4
#
#                                     address
# 0   9253 Richardson Road, Matawan, NJ 07747
# 1          33 Spring Dr., Taunton, MA 02780
# 2          41 Hill Avenue, Mentor, OH 44060
# 3        8839 Marshall St., Miami, FL 33125
# 4  8304 Charles Rd., Lewis Center, OH 43035

# %%
# Solution!!!(part 2)

df['mosthours'] = df['hours'].rank(ascending=1)
df
# Out:
#           fname     lname  gender  age  exercise  hours  grade  \
# 0        Marcia      Pugh  female   17         3     10   82.4
# 1        Kadeem  Morrison    male   18         4      4   78.2
# 2          Nash    Powell    male   18         5      9   79.3
# 3       Noelani    Wagner  female   14         2      7   83.2
# 4       Noelani    Cherry  female   18         4     15   87.4
# ...         ...       ...     ...  ...       ...    ...    ...
# 1995       Cody  Shepherd    male   19         1      8   80.1
# 1996  Geraldine  Peterson  female   16         4     18  100.0
# 1997   Mercedes      Leon  female   18         3     14   84.9
# 1998     Lucius   Rowland    male   16         1      7   69.1
# 1999      Linus    Morris    male   19         4     10   79.6
#
#                                           address  mosthours
# 0         9253 Richardson Road, Matawan, NJ 07747      810.5
# 1                33 Spring Dr., Taunton, MA 02780       89.5
# ...

# %%
# Solution!!!(part 3)

df[df['mosthours'] > 1950].sort_values('mosthours')
# Out:
#           fname        lname  gender  age  exercise  hours  grade  \
# 17        Libby       Guzman  female   19         1     19  100.0
# 804       Jamal       Morton    male   16         4     19  100.0
# 868       Craig        Moses    male   19         4     19  100.0
# 1964    Zenaida      Maynard  female   16         2     19   91.3
# 899      Carson         Mack    male   16         5     19   94.9
# 1029      Clare  Fitzpatrick  female   14         4     19   94.2
# 1104      Myles       Farmer    male   19         2     19  100.0
# 1184    Illiana    Donaldson  female   17         5     19   93.6
# 1195       Yael       Hardin  female   15         1     19   91.4
# 752        Cade        Hogan    male   18         5     19   98.0
# 1269  Valentine     Cummings    male   14         5     19  100.0
# 1725    Leonard         Lynn    male   16         1     19   95.6
# 1794    Jackson      Ballard    male   19         1     19   91.2
# ...

# %%
# Create a Column Based on a Conditional

# %%
# Sometimes, you need to classify a row of data by the values in one or more
# columns, such as identifying those students who are passing or failing by
# whether their grade is above or below 70. In this section, we will learn how
# to do this (Listing 3-40)

# %%
# Listing 3-40. Load Data from CSV
import pandas as pd
Location = "datasets/gradedata.csv" 
df = pd.read_csv(Location) 
df.head()
# Out:
#      fname     lname  gender  age  exercise  hours  grade  \
# 0   Marcia      Pugh  female   17         3     10   82.4
# 1   Kadeem  Morrison    male   18         4      4   78.2
# 2     Nash    Powell    male   18         5      9   79.3
# 3  Noelani    Wagner  female   14         2      7   83.2
# 4  Noelani    Cherry  female   18         4     15   87.4
#
#                                     address
# 0   9253 Richardson Road, Matawan, NJ 07747
# 1          33 Spring Dr., Taunton, MA 02780
# 2          41 Hill Avenue, Mentor, OH 44060
# 3        8839 Marshall St., Miami, FL 33125
# 4  8304 Charles Rd., Lewis Center, OH 43035

# %%
# Now, let us say we want a column indicating whether students are
# failing or not (Listing 3-41).

# %%
# Listing 3-41. Create Yes/No isFailing Column
import numpy as np
df['isFailing'] = np.where(df['grade']<70, 'yes', 'no')
df.tail(10)
# Out:
#           fname     lname  gender  age  exercise  hours  grade  \
# 1990      Adena    Battle  female   17         2      8   70.2
# 1991      Craig    Obrien    male   16         3      7   64.9
# 1992   Isabelle    Barber  female   14         5      9   78.5
# 1993       Risa    Watson  female   14         2     10   74.3
# 1994    Emerson      Gill    male   17         5      5   67.5
# 1995       Cody  Shepherd    male   19         1      8   80.1
# 1996  Geraldine  Peterson  female   16         4     18  100.0
# 1997   Mercedes      Leon  female   18         3     14   84.9
# 1998     Lucius   Rowland    male   16         1      7   69.1
# 1999      Linus    Morris    male   19         4     10   79.6
#
#                                             address isFailing
# 1990    9272 Elizabeth Drive, Londonderry, NH 03053        no
# 1991             524 Park Ave., Hollywood, FL 33020       yes
# 1992      955 Glen Ridge Rd., Plattsburgh, NY 12901        no
# ...

# %%
# Line 1: We import the numpy library
# Line 2: Create a new column called df.failing
# where the value is yes if df.grade is less than 70 and
# no if not.
# If instead we needed a column indicating who the male students were
# with failing scores, we could use the code in Listing 3-42.

# %%
# Listing 3-42. Create Yes/No isFailingMale Column
df['isFailingMale'] = np.where((df['grade']<70) & (df['gender'] == 'male'),'yes', 'no')
df.tail(10)
# Out:
#           fname     lname  gender  age  exercise  hours  grade  \
# 1990      Adena    Battle  female   17         2      8   70.2
# 1991      Craig    Obrien    male   16         3      7   64.9
# 1992   Isabelle    Barber  female   14         5      9   78.5
# 1993       Risa    Watson  female   14         2     10   74.3
# 1994    Emerson      Gill    male   17         5      5   67.5
# 1995       Cody  Shepherd    male   19         1      8   80.1
# 1996  Geraldine  Peterson  female   16         4     18  100.0
# 1997   Mercedes      Leon  female   18         3     14   84.9
# 1998     Lucius   Rowland    male   16         1      7   69.1
# 1999      Linus    Morris    male   19         4     10   79.6
#
#                                             address isFailing isFailingMale
# 1990    9272 Elizabeth Drive, Londonderry, NH 03053        no            no
# 1991             524 Park Ave., Hollywood, FL 33020       yes           yes
# ...

# %%
# Your Turn!!! (Workbook Assignment 4)
# Can you create a column for timemgmt that shows busy if a student exercises more than three hours 
# per week AND studies more than seventeen hours per week?

# %%
# Making New Columns Using Functions

# %%
# Much of what I used to use Excel to do (and what I now use Python for) is
# to create new columns based on an existing one. So, using the following
# data (Listing 3-43), let's see how we would do this

# %%
# Listing 3-43. Load Data from CSV
import pandas as pd
Location = "datasets/gradedata.csv" 
df = pd.read_csv(Location) 
df.head()
# Out:
#      fname     lname  gender  age  exercise  hours  grade  \
# 0   Marcia      Pugh  female   17         3     10   82.4
# 1   Kadeem  Morrison    male   18         4      4   78.2
# 2     Nash    Powell    male   18         5      9   79.3
# 3  Noelani    Wagner  female   14         2      7   83.2
# 4  Noelani    Cherry  female   18         4     15   87.4
#
#                                     address
# 0   9253 Richardson Road, Matawan, NJ 07747
# 1          33 Spring Dr., Taunton, MA 02780
# 2          41 Hill Avenue, Mentor, OH 44060
# 3        8839 Marshall St., Miami, FL 33125
# 4  8304 Charles Rd., Lewis Center, OH 43035

# %%
# To create a single column to contain the full name of each student,
# we first create a function to create a single string from two strings
# (Listing 3-44).

# %%
# Listing 3-44. Create Function to Generate Full Name
def singlename(fn, ln):
    return fn + " " + ln

# %%
# Now, if you test that function, you will see that it works perfectly well
# concatenating Adam and Smith into Adam Smith. However, we can also
# use it with column selectors to create a new column using our fname and
# lname columns (Listing 3-45).

# %%
# Listing 3-45. Create Column to Hold the Full Name
df['fullname'] = singlename(df['fname'],df['lname'])
df
# Out:
#           fname     lname  gender  age  exercise  hours  grade  \
# 0        Marcia      Pugh  female   17         3     10   82.4
# 1        Kadeem  Morrison    male   18         4      4   78.2
# 2          Nash    Powell    male   18         5      9   79.3
# 3       Noelani    Wagner  female   14         2      7   83.2
# 4       Noelani    Cherry  female   18         4     15   87.4
# ...         ...       ...     ...  ...       ...    ...    ...
# 1995       Cody  Shepherd    male   19         1      8   80.1
# 1996  Geraldine  Peterson  female   16         4     18  100.0
# 1997   Mercedes      Leon  female   18         3     14   84.9
# 1998     Lucius   Rowland    male   16         1      7   69.1
# 1999      Linus    Morris    male   19         4     10   79.6
#
#                                           address            fullname
# 0         9253 Richardson Road, Matawan, NJ 07747         Marcia Pugh
# ...

# %%
# This code creates a column called fullname that concatenates the first
# and last name

# %%
# Your Turn!!!
# Can you create a column called total time that adds together the hours of study per week and the hours 
# of exercise per week?

# Solution!!!
import pandas as pd
Location = "datasets/gradedata.csv" 
df = pd.read_csv(Location) 
df.head()

def addstudyexercisehours(study, exercise):
    return study + exercise

df['totaltime'] = addstudyexercisehours(df['hours'],df['exercise'])
df
# Out:
#           fname     lname  gender  age  exercise  hours  grade  \
# 0        Marcia      Pugh  female   17         3     10   82.4
# 1        Kadeem  Morrison    male   18         4      4   78.2
# 2          Nash    Powell    male   18         5      9   79.3
# 3       Noelani    Wagner  female   14         2      7   83.2
# 4       Noelani    Cherry  female   18         4     15   87.4
# ...         ...       ...     ...  ...       ...    ...    ...
# 1995       Cody  Shepherd    male   19         1      8   80.1
# 1996  Geraldine  Peterson  female   16         4     18  100.0
# 1997   Mercedes      Leon  female   18         3     14   84.9
# 1998     Lucius   Rowland    male   16         1      7   69.1
# 1999      Linus    Morris    male   19         4     10   79.6
#
#                                           address  totaltime
# 0         9253 Richardson Road, Matawan, NJ 07747         13
# 1                33 Spring Dr., Taunton, MA 02780          8
# ...

# %%
# Converting String Categories to Numeric
# Variables

# %%
# Why do I need to convert string categories to numeric variables? Many
# analytical tools won't work on text, but if you convert those values to
# numbers it makes things much simpler (Listing 3-46).

# %%
# Listing 3-46. Load Data from CSV
import pandas as pd
df = pd.read_csv(Location) 
df.head()
# Out:
#      fname     lname  gender  age  exercise  hours  grade  \
# 0   Marcia      Pugh  female   17         3     10   82.4
# 1   Kadeem  Morrison    male   18         4      4   78.2
# 2     Nash    Powell    male   18         5      9   79.3
# 3  Noelani    Wagner  female   14         2      7   83.2
# 4  Noelani    Cherry  female   18         4     15   87.4
#
#                                     address
# 0   9253 Richardson Road, Matawan, NJ 07747
# 1          33 Spring Dr., Taunton, MA 02780
# 2          41 Hill Avenue, Mentor, OH 44060
# 3        8839 Marshall St., Miami, FL 33125
# 4  8304 Charles Rd., Lewis Center, OH 43035

# %%
# Method 1: Convert single column to hold numeric variables
# (Listing 3-47).

# %%
# Listing 3-47. Function to Convert Gender to Number
def score_to_numeric(x):
    if x=='female':
        return 1
    if x=='male':
        return 0

# %%
# Now, run that method on your column (Listing 3-48).

# %%
# Listing 3-48. Apply score_to_numeric Function to Gender
df['gender_val'] = df['gender'].apply(score_to_numeric) 
df.tail()
# Out:
#           fname     lname  gender  age  exercise  hours  grade  \
# 1995       Cody  Shepherd    male   19         1      8   80.1
# 1996  Geraldine  Peterson  female   16         4     18  100.0
# 1997   Mercedes      Leon  female   18         3     14   84.9
# 1998     Lucius   Rowland    male   16         1      7   69.1
# 1999      Linus    Morris    male   19         4     10   79.6
#
#                                           address  gender_val
# 1995        982 West Street, Alexandria, VA 22304           0
# 1996   78 Morris Street, East Northport, NY 11731           1
# 1997        30 Glenridge Rd., Bountiful, UT 84010           1
# 1998  342 West Meadowbrook Lane, Helena, MT 59601           0
# 1999       81 Homestead Drive, Voorhees, NJ 08043           0

# %%
# Method 2: Create individual Boolean columns (Listing 3-49).

# %%
# Listing 3-49. Create Boolean Columns Based on Gender Column
df_gender = pd.get_dummies(df['gender']) 
df_gender.tail()
# Out:
#       female  male
# 1995       0     1
# 1996       1     0
# 1997       1     0
# 1998       0     1
# 1999       0     1

# %%
# Join columns to original dataset (Listing 3-50).

# %%
# Listing 3-50. Add New Columns to Original Dataframe
# Join the dummy variables to the main dataframe 
df_new = pd.concat([df, df_gender], axis=1) 
df_new.tail()
# Out:
#           fname     lname  gender  age  exercise  hours  grade  \
# 1995       Cody  Shepherd    male   19         1      8   80.1
# 1996  Geraldine  Peterson  female   16         4     18  100.0
# 1997   Mercedes      Leon  female   18         3     14   84.9
# 1998     Lucius   Rowland    male   16         1      7   69.1
# 1999      Linus    Morris    male   19         4     10   79.6
#
#                                           address  gender_val  female  male
# 1995        982 West Street, Alexandria, VA 22304           0       0     1
# 1996   78 Morris Street, East Northport, NY 11731           1       1     0
# 1997        30 Glenridge Rd., Bountiful, UT 84010           1       1     0
# 1998  342 West Meadowbrook Lane, Helena, MT 59601           0       0     1
# 1999       81 Homestead Drive, Voorhees, NJ 08043           0       0     1

# %%
# or
# Alterative for joining the new columns 
df_new = df.join(df_gender) 
df_new.tail()
# Out:
#           fname     lname  gender  age  exercise  hours  grade  \
# 1995       Cody  Shepherd    male   19         1      8   80.1
# 1996  Geraldine  Peterson  female   16         4     18  100.0
# 1997   Mercedes      Leon  female   18         3     14   84.9
# 1998     Lucius   Rowland    male   16         1      7   69.1
# 1999      Linus    Morris    male   19         4     10   79.6
#
#                                           address  gender_val  female  male
# 1995        982 West Street, Alexandria, VA 22304           0       0     1
# 1996   78 Morris Street, East Northport, NY 11731           1       1     0
# 1997        30 Glenridge Rd., Bountiful, UT 84010           1       1     0
# 1998  342 West Meadowbrook Lane, Helena, MT 59601           0       0     1
# 1999       81 Homestead Drive, Voorhees, NJ 08043           0       0     1

# %%
# Your Turn!!!
# Using datasets/gradesdatawithyear.csv, can you create a numeric column to replace statuses 
# of freshman through senior with the numerals 1 through 4?

# Solution!!!(part 1)

import pandas as pd
import numpy as np

df=pd.read_csv("datasets/gradesdatawithyear.csv")
df
# Out:
#           fname     lname  gender  age       year  exercise  hours  grade  \
# 0        Marcia      Pugh  female   17     junior         3     10   82.4
# 1        Kadeem  Morrison    male   18     senior         4      4   78.2
# 2          Nash    Powell    male   18     senior         5      9   79.3
# 3       Noelani    Wagner  female   14   freshman         2      7   83.2
# 4       Noelani    Cherry  female   18     senior         4     15   87.4
# ...         ...       ...     ...  ...        ...       ...    ...    ...
# 1995       Cody  Shepherd    male   19     senior         1      8   80.1
# 1996  Geraldine  Peterson  female   16  sophomore         4     18  100.0
# 1997   Mercedes      Leon  female   18     senior         3     14   84.9
# 1998     Lucius   Rowland    male   16  sophomore         1      7   69.1
# 1999      Linus    Morris    male   19     senior         4     10   79.6
#
#                                           address
# ...

# %%
# Solution!!!(part 2)

def collegeyear_to_numeric(x):
    if x=='senior':
        return 4
    if x=='junior':
        return 3
    if x=='sophomore':
        return 2
    if x=='freshman':
        return 1

# %%
# Solution!!!(part 3)

df['year_val'] = df['year'].apply(collegeyear_to_numeric) 
df.tail()
# Out:
#           fname     lname  gender  age       year  exercise  hours  grade  \
# 1995       Cody  Shepherd    male   19     senior         1      8   80.1
# 1996  Geraldine  Peterson  female   16  sophomore         4     18  100.0
# 1997   Mercedes      Leon  female   18     senior         3     14   84.9
# 1998     Lucius   Rowland    male   16  sophomore         1      7   69.1
# 1999      Linus    Morris    male   19     senior         4     10   79.6
#
#                                           address  year_val
# 1995        982 West Street, Alexandria, VA 22304         4
# 1996   78 Morris Street, East Northport, NY 11731         2
# 1997        30 Glenridge Rd., Bountiful, UT 84010         4
# 1998  342 West Meadowbrook Lane, Helena, MT 59601         2
# 1999       81 Homestead Drive, Voorhees, NJ 08043         4

# %%
# Organizing the Data

# %%
# Both original and newly created variables need to be formatted correctly
# for two reasons.
# First, so our analysis tools work with them correctly. Failing to format
# a missing value code or a dummy variable correctly will have major
# consequences for your data analysis.
# Second, it's much faster to run the analysis and interpret results if you
# don't have to keep looking up which variable Q156 is.

# %%
# Examples include the following:
# • Removing columns that aren't needed
# • Changing column names
# • Changing column names to lower case
# • Formatting date variables as dates, and so forth.

# %%
# Removing and Adding Columns

# %%
# Sometimes we need to adjust the data. Either something is left out that
# should have been included or something was left in that should have been
# removed. So, let's start with the dataset in Listing 3-51.

# %%
# Listing 3-51. Creating Starting Dataset
import pandas as pd
names = ['Bob','Jessica','Mary','John','Mel']
grades = [76,95,77,78,99]
bsdegrees = [1,1,0,0,1]
msdegrees = [2,1,0,0,0]
phddegrees = [0,1,0,0,0]
GradeList = zip(names,grades,bsdegrees,msdegrees,
 phddegrees)
columns=['Names','Grades','BS','MS','PhD']
df = pd.DataFrame(data = GradeList, columns=columns)
df
# Out:
#      Names  Grades  BS  MS  PhD
# 0      Bob      76   1   2    0
# 1  Jessica      95   1   1    1
# 2     Mary      77   0   0    0
# 3     John      78   0   0    0
# 4      Mel      99   1   0    0

# %%
# We can drop a column by simply adding the code in Listing 3-52

# %%
# Listing 3-52. Dropping a Column
df.drop('PhD', axis=1)
# Out:
#      Names  Grades  BS  MS
# 0      Bob      76   1   2
# 1  Jessica      95   1   1
# 2     Mary      77   0   0
# 3     John      78   0   0
# 4      Mel      99   1   0

# %%
# With axis=1 telling drop that we want to drop a column (1) and not a
# row (0).
# We can add a column filled with zeros by setting the new column name
# to be equal to a 0 (Listing 3-53).

# %%
# Listing 3-53. Creating a New Column Filled with Zeros
df['HighSchool']=0
df
# Out:
#      Names  Grades  BS  MS  PhD  HighSchool
# 0      Bob      76   1   2    0           0
# 1  Jessica      95   1   1    1           0
# 2     Mary      77   0   0    0           0
# 3     John      78   0   0    0           0
# 4      Mel      99   1   0    0           0

# %%
# If, however, you want to set the new columns to equal null values, you
# can do that too (Listing 3-54).

# %%
# Listing 3-54. Creating a New Column Filled with Null Values
import numpy as np
df['PreSchool'] = np.nan
df
# Out:
#      Names  Grades  BS  MS  PhD  HighSchool  PreSchool
# 0      Bob      76   1   2    0           0        NaN
# 1  Jessica      95   1   1    1           0        NaN
# 2     Mary      77   0   0    0           0        NaN
# 3     John      78   0   0    0           0        NaN
# 4      Mel      99   1   0    0           0        NaN

# %%
# Now, adding a column with values is not that hard. We create a series
# and set the column equal to the series (Listing 3-55).

# %%
# Listing 3-55. Creating a New Column Filled with Values
d = ([0,1,0,1,0])
s = pd.Series(d, index= df.index)
df['DriversLicense'] = s
df
# Out:
#      Names  Grades  BS  MS  PhD  HighSchool  PreSchool  DriversLicense
# 0      Bob      76   1   2    0           0        NaN               0
# 1  Jessica      95   1   1    1           0        NaN               1
# 2     Mary      77   0   0    0           0        NaN               0
# 3     John      78   0   0    0           0        NaN               1
# 4      Mel      99   1   0    0           0        NaN               0

# %%
# Your Turn!!!
# Can you remove the bs, ms, and phd degree columns?
# Can you add a Hogwarts Magic Degree column? Everyone but Jessica
# has one; does that make it harder? No? Then I have to be sure to stump you
# next time.

# Solution!!!(part 1)

import pandas as pd
import numpy as np
names=['Bob','Jessica','Mary','John','Mel']
grades=[76,95,77,78,99]
bsdegrees=[1,1,0,0,1]
msdegrees = [2,1,0,0,0]
phddegrees = [0,1,0,0,0]
GradeList=zip(names,grades,bsdegrees,msdegrees,phddegrees)
columns=['Names','Grades','BS','MS','PhD']
df=pd.DataFrame(data=GradeList,columns=columns)
df

# %%
# Solution!!!(part 2)

df1 = df.drop(['BS','MS','PhD'], axis=1)
df1
# Out:
#      Names  Grades
# 0      Bob      76
# 1  Jessica      95
# 2     Mary      77
# 3     John      78
# 4      Mel      99

# %%
# Solution!!!(part 2)

df1["Hogwarts Magic Degree"]=1
df1
# Out:
#      Names  Grades  Hogwarts Magic Degree
# 0      Bob      76                      1
# 1  Jessica      95                      1
# 2     Mary      77                      1
# 3     John      78                      1
# 4      Mel      99                      1

# %%
# Solution!!!(part 3)

d1=([1,0,1,1,1])
s1=pd.Series(d1,index=df1.index)
df1["Hogwarts Magic Degree"] =s1
df1
# Out:
#      Names  Grades  Hogwarts Magic Degree
# 0      Bob      76                      1
# 1  Jessica      95                      0
# 2     Mary      77                      1
# 3     John      78                      1
# 4      Mel      99                      1

# %%
# Selecting Columns

# %%
# You will need to make subselections of your data occasionally, especially if
# your dataset has tons of columns. Here, we learn how to create a dataframe
# that includes only some of our columns (Listing 3-56).

# %%
# Listing 3-56. Load Data from CSV
import pandas as pd
Location = "datasets/gradedata.csv"
df = pd.read_csv(Location)
df.head()
# Out:
#      fname     lname  gender  age  exercise  hours  grade  \
# 0   Marcia      Pugh  female   17         3     10   82.4
# 1   Kadeem  Morrison    male   18         4      4   78.2
# 2     Nash    Powell    male   18         5      9   79.3
# 3  Noelani    Wagner  female   14         2      7   83.2
# 4  Noelani    Cherry  female   18         4     15   87.4
#
#                                     address
# 0   9253 Richardson Road, Matawan, NJ 07747
# 1          33 Spring Dr., Taunton, MA 02780
# 2          41 Hill Avenue, Mentor, OH 44060
# 3        8839 Marshall St., Miami, FL 33125
# 4  8304 Charles Rd., Lewis Center, OH 43035

# %%
# Now, to select a column of data, we specify the column name
# (Listing 3-57).

# %%
# Listing 3-57. Selecting a Column into a List
df['fname']
# Out:
# 0          Marcia
# 1          Kadeem
# 2            Nash
# 3         Noelani
# 4         Noelani
#           ...
# 1995         Cody
# 1996    Geraldine
# 1997     Mercedes
# 1998       Lucius
# 1999        Linus
# Name: fname, Length: 2000, dtype: object

# %%
# But if you run that code you only get the data in the column (notice
# the header is missing). That is because this doesn't return a dataframe; it
# returns a list. To return a dataframe when selecting a column, we need to
# specify it (Listing 3-58).

# %%
# Listing 3-58. Selecting a Column into a Dataframe
df[['fname']]
# Out:
#           fname
# 0        Marcia
# 1        Kadeem
# 2          Nash
# 3       Noelani
# 4       Noelani
# ...         ...
# 1995       Cody
# 1996  Geraldine
# 1997   Mercedes
# 1998     Lucius
# 1999      Linus
#
# [2000 rows x 1 columns]

# %%
# To return multiple columns, we use code like that in Listing 3-59.

# %%
# Listing 3-59. Selecting Multiple Columns into a Dataframe
df[['fname','age','grade']]
# Out:
#           fname  age  grade
# 0        Marcia   17   82.4
# 1        Kadeem   18   78.2
# 2          Nash   18   79.3
# 3       Noelani   14   83.2
# 4       Noelani   18   87.4
# ...         ...  ...    ...
# 1995       Cody   19   80.1
# 1996  Geraldine   16  100.0
# 1997   Mercedes   18   84.9
# 1998     Lucius   16   69.1
# 1999      Linus   19   79.6
#
# [2000 rows x 3 columns]

# %%
# And, of course, if we want to create a dataframe with that subset of
# columns, we can copy it to another variable (Listing 3-60).

# %%
# Listing 3-60. Creating New Dataframe from Your Selection
df2 = df[['fname','age','grade']]
df2.head()
# Out:
#      fname  age  grade
# 0   Marcia   17   82.4
# 1   Kadeem   18   78.2
# 2     Nash   18   79.3
# 3  Noelani   14   83.2
# 4  Noelani   18   87.4

# %%
# Your Turn!!!
# We need to create a mailing list. Can you create a new dataframe by
# selecting the first name, last name, and address fields?

# Solution!!!(part 1)

import pandas as pd
df=pd.read_csv("datasets/gradedata.csv")
df
# Out:
#           fname     lname  gender  age  exercise  hours  grade  \
# 0        Marcia      Pugh  female   17         3     10   82.4
# 1        Kadeem  Morrison    male   18         4      4   78.2
# 2          Nash    Powell    male   18         5      9   79.3
# 3       Noelani    Wagner  female   14         2      7   83.2
# 4       Noelani    Cherry  female   18         4     15   87.4
# ...         ...       ...     ...  ...       ...    ...    ...
# 1995       Cody  Shepherd    male   19         1      8   80.1
# 1996  Geraldine  Peterson  female   16         4     18  100.0
# 1997   Mercedes      Leon  female   18         3     14   84.9
# 1998     Lucius   Rowland    male   16         1      7   69.1
# 1999      Linus    Morris    male   19         4     10   79.6
#
#                                           address
# 0         9253 Richardson Road, Matawan, NJ 07747
# 1                33 Spring Dr., Taunton, MA 02780
# 2                41 Hill Avenue, Mentor, OH 44060
# ...

# %%
# Solution!!!(part 2)

df1=df[["fname","lname",'address']]
df1
# Out:
#           fname     lname                                      address
# 0        Marcia      Pugh      9253 Richardson Road, Matawan, NJ 07747
# 1        Kadeem  Morrison             33 Spring Dr., Taunton, MA 02780
# 2          Nash    Powell             41 Hill Avenue, Mentor, OH 44060
# 3       Noelani    Wagner           8839 Marshall St., Miami, FL 33125
# 4       Noelani    Cherry     8304 Charles Rd., Lewis Center, OH 43035
# ...         ...       ...                                          ...
# 1995       Cody  Shepherd        982 West Street, Alexandria, VA 22304
# 1996  Geraldine  Peterson   78 Morris Street, East Northport, NY 11731
# 1997   Mercedes      Leon        30 Glenridge Rd., Bountiful, UT 84010
# 1998     Lucius   Rowland  342 West Meadowbrook Lane, Helena, MT 59601
# 1999      Linus    Morris       81 Homestead Drive, Voorhees, NJ 08043
#
# [2000 rows x 3 columns]

# %%
# Change Column Name

# %%
# Sometimes you need change the names of your columns. With pandas, it's
# easy to do. First, you load your data (Listing 3-61).

# %%
# Listing 3-61. Load Dataset from CSV
import pandas as pd
Location = "datasets/gradedata.csv"
df = pd.read_csv(Location)
df.head()
# Out:
#      fname     lname  gender  age  exercise  hours  grade  \
# 0   Marcia      Pugh  female   17         3     10   82.4
# 1   Kadeem  Morrison    male   18         4      4   78.2
# 2     Nash    Powell    male   18         5      9   79.3
# 3  Noelani    Wagner  female   14         2      7   83.2
# 4  Noelani    Cherry  female   18         4     15   87.4
#
#                                     address
# 0   9253 Richardson Road, Matawan, NJ 07747
# 1          33 Spring Dr., Taunton, MA 02780
# 2          41 Hill Avenue, Mentor, OH 44060
# 3        8839 Marshall St., Miami, FL 33125
# 4  8304 Charles Rd., Lewis Center, OH 43035

# %%
# But, when we look at the header, we aren't crazy about the column
# names—or it doesn't have any.
# It is simple to change the column headers (Listing 3-62).

# %%
# Listing 3-62. Change All Headers
df.columns = ['FirstName', 'LastName', 'Gender',
 'Age', 'HoursExercisePerWeek',
 'HoursStudyPerWeek', 'LetterGrade',
 'StreetAddress']
df.head()
# Out:
#   FirstName  LastName  Gender  Age  HoursExercisePerWeek  HoursStudyPerWeek  \
# 0    Marcia      Pugh  female   17                     3                 10
# 1    Kadeem  Morrison    male   18                     4                  4
# 2      Nash    Powell    male   18                     5                  9
# 3   Noelani    Wagner  female   14                     2                  7
# 4   Noelani    Cherry  female   18                     4                 15
#
#    LetterGrade                             StreetAddress
# 0         82.4   9253 Richardson Road, Matawan, NJ 07747
# 1         78.2          33 Spring Dr., Taunton, MA 02780
# 2         79.3          41 Hill Avenue, Mentor, OH 44060
# 3         83.2        8839 Marshall St., Miami, FL 33125
# 4         87.4  8304 Charles Rd., Lewis Center, OH 43035

# %%
# Or, if you just wanted to change one or two values, you can load the list
# of headers (Listing 3-63).

# %%
# Listing 3-63. Load List of Headers into a Temp Variable
headers = list(df.columns.values)

# %%
# Once the headers are loaded, you can change a few (Listing 3-64).

# %%
# Listing 3-64. Changing Headers
headers[0] = 'FName'
headers[1] = 'LName'
df.columns = headers
df.head()
# Out:
#      FName     LName  Gender  Age  HoursExercisePerWeek  HoursStudyPerWeek  \
# 0   Marcia      Pugh  female   17                     3                 10
# 1   Kadeem  Morrison    male   18                     4                  4
# 2     Nash    Powell    male   18                     5                  9
# 3  Noelani    Wagner  female   14                     2                  7
# 4  Noelani    Cherry  female   18                     4                 15
#
#    LetterGrade                             StreetAddress
# 0         82.4   9253 Richardson Road, Matawan, NJ 07747
# 1         78.2          33 Spring Dr., Taunton, MA 02780
# 2         79.3          41 Hill Avenue, Mentor, OH 44060
# 3         83.2        8839 Marshall St., Miami, FL 33125
# 4         87.4  8304 Charles Rd., Lewis Center, OH 43035

# %%
# Your Turn!!!
# Can you change the age column name to years?

# Solution!!!

headers[3] = "years"
df.columns = headers
df.head()
# Out:
#      FName     LName  Gender  years  HoursExercisePerWeek  HoursStudyPerWeek  \
# 0   Marcia      Pugh  female     17                     3                 10
# 1   Kadeem  Morrison    male     18                     4                  4
# 2     Nash    Powell    male     18                     5                  9
# 3  Noelani    Wagner  female     14                     2                  7
# 4  Noelani    Cherry  female     18                     4                 15
#
#    LetterGrade                             StreetAddress
# 0         82.4   9253 Richardson Road, Matawan, NJ 07747
# 1         78.2          33 Spring Dr., Taunton, MA 02780
# 2         79.3          41 Hill Avenue, Mentor, OH 44060
# 3         83.2        8839 Marshall St., Miami, FL 33125
# 4         87.4  8304 Charles Rd., Lewis Center, OH 43035

# %%
# Setting Column Names to Lower Case

# %%
# It may not be the biggest problem in the world, but sometimes I need to
# convert all the column names to lowercase (or uppercase, for that matter).
# This lesson will cover how to do that (Listing 3-65).

# %%
# Listing 3-65. Load Data from CSV
import pandas as pd
Location = "datasets/gradedata.csv"
df = pd.read_csv(Location)
df.head()
# Out:
#      fname     lname  gender  age  exercise  hours  grade  \
# 0   Marcia      Pugh  female   17         3     10   82.4
# 1   Kadeem  Morrison    male   18         4      4   78.2
# 2     Nash    Powell    male   18         5      9   79.3
# 3  Noelani    Wagner  female   14         2      7   83.2
# 4  Noelani    Cherry  female   18         4     15   87.4
#
#                                     address
# 0   9253 Richardson Road, Matawan, NJ 07747
# 1          33 Spring Dr., Taunton, MA 02780
# 2          41 Hill Avenue, Mentor, OH 44060
# 3        8839 Marshall St., Miami, FL 33125
# 4  8304 Charles Rd., Lewis Center, OH 43035

# %%
# Once you have the data, there are two quick ways to cast all the column
# headers to lowercase (Listing 3-66).

# %%
# Listing 3-66. Casting All Headers to Lowercase
# method 1
df.columns = map(str.lower, df.columns)
# method 2
df.columns = [x.lower() for x in df.columns]

# %%
# Your Turn!!!
# Can you figure out how to make all the column headers all uppercase?

# Solution!!!

df.columns = map(str.upper, df.columns)
# method 2
df.columns = [x.upper() for x in df.columns]
df
# Out:
#           FNAME     LNAME  GENDER  AGE  EXERCISE  HOURS  GRADE  \
# 0        Marcia      Pugh  female   17         3     10   82.4
# 1        Kadeem  Morrison    male   18         4      4   78.2
# 2          Nash    Powell    male   18         5      9   79.3
# 3       Noelani    Wagner  female   14         2      7   83.2
# 4       Noelani    Cherry  female   18         4     15   87.4
# ...         ...       ...     ...  ...       ...    ...    ...
# 1995       Cody  Shepherd    male   19         1      8   80.1
# 1996  Geraldine  Peterson  female   16         4     18  100.0
# 1997   Mercedes      Leon  female   18         3     14   84.9
# 1998     Lucius   Rowland    male   16         1      7   69.1
# 1999      Linus    Morris    male   19         4     10   79.6
#
#                                           ADDRESS
# 0         9253 Richardson Road, Matawan, NJ 07747
# 1                33 Spring Dr., Taunton, MA 02780
# 2                41 Hill Avenue, Mentor, OH 44060
# ...

# %%
# Finding Matching Rows

# %%
# Of course, you don't always want to compute using the entire dataset.
# Sometimes you want to work with just a subset of your data. In this lesson,
# we find out how to do that (Listing 3-67).

# %%
# Listing 3-67. Creating Dataset
import pandas as pd
names = ['Bob','Jessica','Mary','John','Mel']
grades = [76,95,77,78,99]
GradeList = zip(names,grades)
df = pd.DataFrame(data = GradeList,
 columns=['Names', 'Grades'])
df
# Out:
#      Names  Grades
# 0      Bob      76
# 1  Jessica      95
# 2     Mary      77
# 3     John      78
# 4      Mel      99

# %%
# To find all the rows that contain the word Mel, use the code shown in
# Listing 3-68 in a new cell.

# %%
# Listing 3-68. Filtering Rows
df['Names'].str.contains('Mel')
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# Name: Names, dtype: bool

# %%
# After executing that line of Python, you will see a list of Boolean
# values—True for the lines that match our query and False for that ones that
# don't.
# We can make our answer shorter by adding .any. This will just display a
# single True if any line matches and False if none of them do (Listing 3-69).

# %%
# Listing 3-69. Check if Any Rows Match
# check if any row matches
df['Names'].str.contains('Mel').any()
# Out:
# True

# %%
# Alternatively, you can add .all. This will just display a single True if all
# of the lines match and False if at least one of them does not (Listing 3-70).

# %%
# Listing 3-70. Check if All Rows Match
# check if all rows match
df['Names'].str.contains('Mel').all()
# Out:
# False

# %%
# We can also use this along with the .loc (locate) function to show just
# the rows that match certain criteria (Listing 3-71).

# %%
# Listing 3-71. Show the Rows that Match
# Find the rows that match a criteria like this
df.loc[df['Names'].str.contains('Mel')==True]
# or even like this...
df.loc[df['Grades']==0]
# Out:
# Empty DataFrame
# Columns: [Names, Grades]
# Index: []

# %%
# Your Turn
# Can you find all the people who have at least one MS degree in the
# following data (Listing 3-72)?

# %%
# Listing 3-72. Starting Dataset
import pandas as pd
names = ['Bob','Jessi','Mary','John','Mel','Sam',
 'Cathy','Hank','Lloyd']
grades = [76,95,77,78,99,84,79,100,73]
bsdegrees = [1,1,0,0,1,1,1,0,1]
msdegrees = [2,1,0,0,0,1,1,0,0]
phddegrees = [0,1,0,0,0,2,1,0,0]
GradeList = zip(names,grades,bsdegrees,msdegrees,
 phddegrees)
df = pd.DataFrame(data = GradeList, columns=['Name','Grade','BS',
'MS','PhD'])
df
# Out:
#     Name  Grade  BS  MS  PhD
# 0    Bob     76   1   2    0
# 1  Jessi     95   1   1    1
# 2   Mary     77   0   0    0
# 3   John     78   0   0    0
# 4    Mel     99   1   0    0
# 5    Sam     84   1   1    2
# 6  Cathy     79   1   1    1
# 7   Hank    100   0   0    0
# 8  Lloyd     73   1   0    0

# %%
# Filter Rows Based on Conditions

# %%
# Listing 3-73. Load Data from CSV
import pandas as pd
Location = "datasets/gradedata.csv"
df = pd.read_csv(Location)
df.head()
# Out:
#      fname     lname  gender  age  exercise  hours  grade  \
# 0   Marcia      Pugh  female   17         3     10   82.4
# 1   Kadeem  Morrison    male   18         4      4   78.2
# 2     Nash    Powell    male   18         5      9   79.3
# 3  Noelani    Wagner  female   14         2      7   83.2
# 4  Noelani    Cherry  female   18         4     15   87.4
#
#                                     address
# 0   9253 Richardson Road, Matawan, NJ 07747
# 1          33 Spring Dr., Taunton, MA 02780
# 2          41 Hill Avenue, Mentor, OH 44060
# 3        8839 Marshall St., Miami, FL 33125
# 4  8304 Charles Rd., Lewis Center, OH 43035

# %%
# We can show one column of data (Listing 3-74).

# %%
# Listing 3-74. One Column
df['grade'].head()
# Out:
# 0    82.4
# 1    78.2
# 2    79.3
# 3    83.2
# 4    87.4
# Name: grade, dtype: float64

# %%
# Or we can show two columns of data (Listing 3-75).

# %%
# Listing 3-75. Two Columns
df[['age','grade']].head()
# Out:
#    age  grade
# 0   17   82.4
# 1   18   78.2
# 2   18   79.3
# 3   14   83.2
# 4   18   87.4

# %%
# Or we can show the first two rows of data (Listing 3-76).

# %%
# Listing 3-76. First Two Rows
df[:2]
# Out:
#     fname     lname  gender  age  exercise  hours  grade  \
# 0  Marcia      Pugh  female   17         3     10   82.4
# 1  Kadeem  Morrison    male   18         4      4   78.2
#
#                                    address
# 0  9253 Richardson Road, Matawan, NJ 07747
# 1         33 Spring Dr., Taunton, MA 02780

# %%
# To show all the rows where the grade is greater than 80, use the code in
# Listing 3-77

# %%
# Listing 3-77. All Rows with Grade > 80
df[df['grade'] > 80]
# Out:
#           fname     lname  gender  age  exercise  hours  grade  \
# 0        Marcia      Pugh  female   17         3     10   82.4
# 3       Noelani    Wagner  female   14         2      7   83.2
# 4       Noelani    Cherry  female   18         4     15   87.4
# 5          Neil   Whitley    male   16         5     16   88.7
# 6         Nelle    Golden  female   17         1      9   80.2
# ...         ...       ...     ...  ...       ...    ...    ...
# 1986     Indigo     Mccoy  female   19         2     14   91.3
# 1989       John      Ford    male   14         2     14   91.2
# 1995       Cody  Shepherd    male   19         1      8   80.1
# 1996  Geraldine  Peterson  female   16         4     18  100.0
# 1997   Mercedes      Leon  female   18         3     14   84.9
#
#                                           address
# 0         9253 Richardson Road, Matawan, NJ 07747
# 3              8839 Marshall St., Miami, FL 33125
# 4        8304 Charles Rd., Lewis Center, OH 43035
# ...

# %%
# Using multiple conditions is a little trickier. So, if we wanted to get a list
# of all the students who scored higher than 99.9 and were male, we would
# need to use the code shown in Listing 3-78.

# %%
# Listing 3-78. All Rows Where Men Scored > 99.9
# NOTE: The book uses .ix attribute which is deprecated.
# Use .loc instead of .ix for index
# check https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.loc.html
# for more detials on .loc
df.loc[(df['grade'] > 99.9) & (df['gender'] == 'male') ]
# Out:
#           fname      lname gender  age  exercise  hours  grade  \
# 36         Ivor     Arnold   male   19         4     20  100.0
# 165      Ciaran      Johns   male   16         4     15  100.0
# 226       Uriah   Cummings   male   18         3     20  100.0
# 303       Kamal     Walton   male   14         1     17  100.0
# 325        Thor      Ramos   male   17         3     18  100.0
# 355      Kadeem   Marshall   male   17         5     18  100.0
# 382       Jacob       Gray   male   15         3     17  100.0
# 473      Declan    Manning   male   18         4     16  100.0
# 616         Ali     Franks   male   18         5     20  100.0
# 644       Drake    Winters   male   17         4     19  100.0
# 690   Sylvester      Payne   male   17         5     20  100.0
# 757       Erich      Stone   male   14         5     17  100.0
# 804       Jamal     Morton   male   16         4     19  100.0
# 825       Kevin      Smith   male   16         5     20  100.0
# ...

# %%
# If instead we wanted all the students who scored higher than 99 OR
# were female, we would need to use the code in Listing 3-79.

# %%
# Listing 3-79. All Rows Where Women or Scored > 99
df.loc[(df['grade'] > 99) | (df['gender'] == 'female') ]
# Out:
#           fname     lname  gender  age  exercise  hours  grade  \
# 0        Marcia      Pugh  female   17         3     10   82.4
# 3       Noelani    Wagner  female   14         2      7   83.2
# 4       Noelani    Cherry  female   18         4     15   87.4
# 6         Nelle    Golden  female   17         1      9   80.2
# 8       Illiana     Rojas  female   15         5      9   76.5
# ...         ...       ...     ...  ...       ...    ...    ...
# 1990      Adena    Battle  female   17         2      8   70.2
# 1992   Isabelle    Barber  female   14         5      9   78.5
# 1993       Risa    Watson  female   14         2     10   74.3
# 1996  Geraldine  Peterson  female   16         4     18  100.0
# 1997   Mercedes      Leon  female   18         3     14   84.9
#
#                                             address
# 0           9253 Richardson Road, Matawan, NJ 07747
# 3                8839 Marshall St., Miami, FL 33125
# ...

# %%
# Your Turn!!!
# Can you show all the rows where the student was male, exercised less than
# two hours per week, and studied more than fifteen hours per week?

# Solution!!!

df.loc[( (df['gender']=='male') & (df['exercise'] < 2) & (df['hours'] > 15) )]
# Out:
#            fname       lname gender  age  exercise  hours  grade  \
# 85        Porter        Ware   male   14         1     16   90.4
# 159       Darius     Miranda   male   19         1     16   93.3
# 184         Lars       David   male   14         1     16   84.3
# 303        Kamal      Walton   male   14         1     17  100.0
# 310     Honorato       Hogan   male   17         1     19   90.1
# 317         Todd  Cunningham   male   16         1     16   81.4
# 351        Nehru     Ballard   male   14         1     19   93.3
# 364     Prescott     Kaufman   male   15         1     17   96.3
# 466        Kuame      Gordon   male   18         1     16   83.5
# 545      Mufutau     Clayton   male   17         1     16   86.0
# 653   Fitzgerald     Hammond   male   18         1     16   85.9
# 673         Nero     Burgess   male   17         1     16   87.6
# 675       Ashton      Mullen   male   16         1     16   80.1
# ...

# %%
# Selecting Rows Based on Conditions

# %%
# Listing 3-80. Load Data from CSV
import pandas as pd
Location = "datasets/gradedata.csv"
df = pd.read_csv(Location)
df.head()
# Out:
#      fname     lname  gender  age  exercise  hours  grade  \
# 0   Marcia      Pugh  female   17         3     10   82.4
# 1   Kadeem  Morrison    male   18         4      4   78.2
# 2     Nash    Powell    male   18         5      9   79.3
# 3  Noelani    Wagner  female   14         2      7   83.2
# 4  Noelani    Cherry  female   18         4     15   87.4
#
#                                     address
# 0   9253 Richardson Road, Matawan, NJ 07747
# 1          33 Spring Dr., Taunton, MA 02780
# 2          41 Hill Avenue, Mentor, OH 44060
# 3        8839 Marshall St., Miami, FL 33125
# 4  8304 Charles Rd., Lewis Center, OH 43035

# %%
# Listing 3-81. Method 1: Using Variables to Hold Attributes
female = df['gender'] == "female"
a_student = df['grade'] >= 90
df[female & a_student].head()
# Out:
#       fname      lname  gender  age  exercise  hours  grade  \
# 17    Libby     Guzman  female   19         1     19  100.0
# 21    Maggy  Whitfield  female   15         1     15   90.5
# 29     Emma     Mccall  female   16         2     13   91.1
# 32  Georgia      Munoz  female   14         5     20   99.0
# 33    Doris   Melendez  female   17         5     12   93.2
#
#                                    address
# 17  666 S. Pennington Rd., Dover, NH 03820
# 21        2 Henry Ave., Palm Bay, FL 32907
# 29   854 Sussex Street, Westford, MA 01886
# 32     84 New Saddle St., Revere, MA 02151
# 33       8 Euclid Drive, Bel Air, MD 21014

# %%
# Line 1: We create a variable with TRUE if gender is
# female.
# Line 2: We create a variable with TRUE if grade is
# greater than or equal to 90.
# Line 3: This is where we select all cases where both
# gender is female and grade is greater than or equal
# to 90.

# %%
# Listing 3-82. Method 2: Using Variable Attributes Directly
df[df['fname'].notnull() & (df['gender'] == "male")]
# Out:
#         fname     lname gender  age  exercise  hours  grade  \
# 1      Kadeem  Morrison   male   18         4      4   78.2
# 2        Nash    Powell   male   18         5      9   79.3
# 5        Neil   Whitley   male   16         5     16   88.7
# 7     Armando   Hoffman   male   17         5     18   95.1
# 9        Neil    Wooten   male   15         3     15   89.7
# ...       ...       ...    ...  ...       ...    ...    ...
# 1991    Craig    Obrien   male   16         3      7   64.9
# 1994  Emerson      Gill   male   17         5      5   67.5
# 1995     Cody  Shepherd   male   19         1      8   80.1
# 1998   Lucius   Rowland   male   16         1      7   69.1
# 1999    Linus    Morris   male   19         4     10   79.6
#
#                                           address
# 1                33 Spring Dr., Taunton, MA 02780
# 2                41 Hill Avenue, Mentor, OH 44060
# 5        40 Washington Ave., Bloomfield, NJ 07003
# ...

# %%
# In Listing 3-82, we select all cases where the first name is not missing
# and gender is male.

# %%
# Your Turn!!!
# Can you find all the rows where the student had four or more hours of
# exercise per week, seventeen or more hours of study, and still had a grade
# that was lower than 80?

# Solution!!!

# For this combination there is no student

df[(df['exercise']>4) & (df['hours']>17) & (df['grade']<80)]
# Out:
# Empty DataFrame
# Columns: [fname, lname, gender, age, exercise, hours, grade, address]
# Index: []

# %%
df[(df['exercise']>4) & (df['hours']>17) & (df['grade']>80)]
# Out:
#           fname      lname  gender  age  exercise  hours  grade  \
# 7       Armando    Hoffman    male   17         5     18   95.1
# 23        Lance   Benjamin    male   14         5     18   90.3
# 26      Solomon  Mcpherson    male   15         5     18   94.5
# 32      Georgia      Munoz  female   14         5     20   99.0
# 71    Christine     Briggs  female   14         5     18   91.9
# 86         Joan     Sexton  female   18         5     18   96.6
# 321    Lysandra   Copeland  female   19         5     19  100.0
# 355      Kadeem   Marshall    male   17         5     18  100.0
# 508         Dai    Osborne  female   19         5     20  100.0
# 616         Ali     Franks    male   18         5     20  100.0
# 621   Gwendolyn    Vazquez  female   19         5     19  100.0
# 690   Sylvester      Payne    male   17         5     20  100.0
# 752        Cade      Hogan    male   18         5     19   98.0
# 767        Lila       Wall  female   17         5     18  100.0
# ...

# %%
# Random Sampling Dataframe

# %%
# This one is simple. Obviously, sometimes we have datasets that are too
# large and we need to take a subset, so let's start with some loaded data
# (Listing 3-83).

# %%
# Listing 3-83. Load Dataset from CSV
import pandas as pd
import numpy as np
Location = "datasets/gradedata.csv"
df = pd.read_csv(Location)
df.tail()
# Out:
#           fname     lname  gender  age  exercise  hours  grade  \
# 1995       Cody  Shepherd    male   19         1      8   80.1
# 1996  Geraldine  Peterson  female   16         4     18  100.0
# 1997   Mercedes      Leon  female   18         3     14   84.9
# 1998     Lucius   Rowland    male   16         1      7   69.1
# 1999      Linus    Morris    male   19         4     10   79.6
#
#                                           address
# 1995        982 West Street, Alexandria, VA 22304
# 1996   78 Morris Street, East Northport, NY 11731
# 1997        30 Glenridge Rd., Bountiful, UT 84010
# 1998  342 West Meadowbrook Lane, Helena, MT 59601
# 1999       81 Homestead Drive, Voorhees, NJ 08043

# %%
# To select just 100 rows randomly from that dataset, we can simply run
# the code shown in Listing 3-84.

# %%
# Listing 3-84. Random Sample of 100 Rows from Dataframe
df.take(np.random.permutation(len(df))[:100])
# Out:
#            fname    lname  gender  age  exercise  hours  grade  \
# 541       Kameko    Flynn  female   17         3     15   86.6
# 939        Wendy  Hawkins  female   15         4      4   69.5
# 653   Fitzgerald  Hammond    male   18         1     16   85.9
# 1969     Randall   Weaver    male   18         1     15   83.1
# 7        Armando  Hoffman    male   17         5     18   95.1
# ...          ...      ...     ...  ...       ...    ...    ...
# 1799       Wanda    Jones  female   16         3     14   84.7
# 1716      Hector   Melton    male   18         4     12   88.2
# 587        Kiona  Collier  female   14         4     11   84.0
# 414     Marshall   Reeves    male   15         4     11   83.0
# 1047      Tobias  Delaney    male   17         3     10   76.2
#
#                                                 address
# 541                 53 Helen Court, Kalispell, MT 59901
# 939              31 Annadale Street, Chandler, AZ 85224
# ...

# %%
# Your Turn!!! (Workbook Assignment 5)
# Can you create a random sample of 500 rows from that dataset?
